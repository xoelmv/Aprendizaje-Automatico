# %% [markdown]
# <a href="https://colab.research.google.com/github/xoelmv/Aprendizaje-Automatico/blob/main/Lab2_Parte_1(Redes_neuronales_desde_cero_con_TensorFlow).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eirasf/GCED-AA2/blob/main/lab2/lab2-parte1.ipynb)
#
# # Práctica 1: Redes neuronales desde cero con TensorFlow
#
# En esta práctica vamos a familiarizarnos con la librería TensorFlow. Para ello, vamos a desarrollar un clasificador que utilice una red neuronal para modelar los datos y hacer predicciones. Esto requiere que diseñemos la red neuronal y que hagamos el entrenamiento para que las predicciones sean correctas para el conjunto de datos dado.
#
#
# # Pre-requisitos
#
# ## Instalar paquetes
#
# Para esta práctica solo necesitaremos NumPy, TensorFlow 2.0 y TensorFlow-Datasets

# %%
# Ejemplo de instalación de tensorflow 2.0
#%tensorflow_version 2.x
# !pip3 install tensorflow numpy tensorflow-datasets
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds

# %% [markdown]
# ## Creación de una neurona artificial con Numpy
#
# Una neurona artificial consta de dos partes diferenciadas. En primer lugar, la unidad realiza una suma de todas sus entradas (más una componente de *bias*), cada una de ellas ponderada por un peso. Estos pesos (y el *bias*) serán los que se modifiquen para conseguir que la neurona dé la salida adecuada para nuestro problema para cada combinación de entradas del conjunto de datos de entrada.
#
# Dado un vector de entrada $\mathbf{x}$ con $d$ componentes y un vector de pesos $\mathbf{w}$, esta primera parte de la neurona calculará un único valor escalar de salida que llamaremos $z$ de la siguiente forma:
#
# $$
# z = \sum \limits_{i=0}^{d} \mathbf{x}_i\mathbf{w}_i + bias
# $$
#
# ### Notación vectorial
#
# Para simplificar la notación, podemos representar todos los pesos de una neurona como un vector. Al hacerlo así, la suma ponderada de las entradas será el producto escalar del vector $\mathbf{x}$ de entrada y el vector $\mathbf{w}$ de pesos. Teniendo en cuenta que asumiremos que el vector de entrada $\mathbf{x}$ es un vector fila de dimensiones 1 x $d$, declararemos el vector de pesos $\mathbf{w}$ con las mismas dimensiones y podremos representar el producto escalar $\mathbf{x} · \mathbf{w}$ como el producto matricial $\mathbf{x}\mathbf{w}^T$. Esto es ventajoso para poder procesar varios vectores de entrada utilizando la misma operación.
#
# $$
# z = \sum \limits_{i=0}^{d} \mathbf{x}_i\mathbf{w}_i + bias = \mathbf{x} · \mathbf{w} + bias = \mathbf{x} \mathbf{w}^T + bias
# $$
#
# Completa la siguiente celda para calcular $z$.

# %%
x = np.array([1, 2, 8, -4]).reshape((1,4)) # vector de entrada
w = np.array([0.1, -0.8, 0.3, 0.2]).reshape((1,4)) # vector de pesos
bias = 0.1

z = np.dot(x,w.T)+bias

# verificación del resultado
np.testing.assert_almost_equal(0.2, z, err_msg='Revisa tu implementación')

# %% [markdown]
# ### Función de activación
#
# Tras este primer paso, la salida $z$ será una combinación lineal de las entradas. Si concatenamos varias neuronas así definidas, el resultado seguirá siendo una combinación lineal de las entradas, lo cual no es muy útil dado que se podría obtener el mismo resultado con una sola neurona. Es por ello que necesitamos que cada neurona tenga una segunda parte que introduzca una no-linealidad. Es lo que denominamos *función de activación*. En este ejemplo tomaremos como función de activación la función sigmoide, definida como:
#
# $$sigmoide(x) = \dfrac{1}{1+e^{-x}}$$
#
# Completa a continuación el código para calcular la sigmoide de un escalar $x$:

# %%
def sigmoide(x):
    return 1/(1+np.exp(-x))

# verificación del resultado
np.testing.assert_almost_equal(0.54983399, sigmoide(z))

# %% [markdown]
# En este caso, tomaremos como entrada de la función sigmoide la salida del paso anterior, $z$. Por tanto, la salida $y$ de la neurona artificial será un escalar de la siguiente forma:
#
# $$y = sigmoide(z) = \dfrac{1}{1+e^{-(\mathbf{x}\mathbf{w}^T + bias)}}$$
#
# Puedes ver el esquema general de una neurona artificial en este diagrama:
#
# <img src="https://github.com/eirasf/GCED-AA2/blob/main/lab2/img/neural-model.png?raw=1" alt="Diagrama de una neurona artificial" width="700"/>
#
# Completa el código de esta función realizar el *forward pass* de una neurona artificial con función de activación sigmoide, es decir, para calcular la salida a partir del vector de entrada, el vector de pesos y el valor de bias:

# %%
def neurona_forward(x, w, bias):
    return sigmoide(np.dot(x,w.T)+bias)

# verificación
np.testing.assert_almost_equal(0.54983399, neurona_forward(x, w, bias))

# %% [markdown]
# ## Red feed-forward
#
# Con este montaje, si utilizásemos descenso de gradiente para aprender el vector $\mathbf{w}$ que haga las predicciones correctas para un conjunto de datos dado, estaríamos entrenando un modelo de regresión logística. Sin embargo, la potencia de las redes neuronales reside en la posibilidad de combinar muchas de estas unidades para poder modelar funciones mucho más complejas, por lo que vamos a construir una red que utilice varias unidades.
#
# El modo más sencillo de organizar varias neuronas es formando una red *feed-forward*. Para ello, primero agruparemos varias neuronas formando una *capa*. Si la salida de una neurona era un escalar $y$, la salida de una capa será un vector $\mathbf{y}$ con tantas componentes como unidades tenga la capa. Igualmente, si en una neurona teníamos un vector $\mathbf{w}$ de pesos, en una capa tendremos una matriz $\mathbf{W}$ de pesos, en la que cada fila corresponderá con el vector de pesos de una neurona de la capa. También tendremos un vector $\mathbf{b}$, donde cada componente será el *bias* de una neurona de la capa.
#
# Podemos aprovechar las operaciones de matrices y vectores de NumPy para hacer el *forward pass* de toda una capa de una sola vez. Completa el siguiente código para obtener una función que realice el *forward pass* de una capa de neuronas artificiales con activación sigmoide tomando como entradas el vector de entrada $\mathbf{x}$, una matriz de pesos $\mathbf{W}$ y un vector $\mathbf{b}$.

# %%
# Asegúrate de que tu implementación de sigmoide puede tomar como entrada un vector. (La función np.exp de NumPy te puede resultar útil, porque puede tomar como entrada un escalar y devolver un escalar, pero también puede tomar un vector y devolver otro vector).
np.testing.assert_almost_equal([0.549834, 0.98201379], sigmoide(np.array([z[0][0],4])))

def capa_forward(x, W, b):
    return sigmoide(np.dot(x,W.T)+b)

# verificación
np.testing.assert_almost_equal(np.array([[0.549834], [0.05732418]]), capa_forward(np.vstack((x, np.array([-1, 3, -2, 2]))), w, np.array([bias, -0.1]).reshape((2,1))))

# %% [markdown]
# Ahora podemos concatenar capas de neuronas con facilidad. Vamos a crear una red de tres capas:
#  1. La capa $C_0$ consta de 5 unidades. Recibe como entrada el vector $\mathbf{x}$ y produce como salida el vector $\mathbf{h_0}$. Tiene una matriz de pesos $\mathbf{W_0}$ y un vector de bias $\mathbf{b_0}$.
#  1. La capa $C_1$ consta de 3 unidades. Recibe como entrada el vector $\mathbf{h_0}$ y produce como salida el vector $\mathbf{h_1}$. Tiene una matriz de pesos $\mathbf{W_1}$ y un vector de bias $\mathbf{b_1}$.
#  1. La capa $C_2$ consta de 1 unidad. Recibe como entrada el vector $\mathbf{h_1}$ y produce como salida el vector $\mathbf{y}$. Tiene una matriz de pesos $\mathbf{W_2}$ y un vector de bias $\mathbf{b_2}$.
#
# <img src="https://github.com/eirasf/GCED-AA2/blob/main/lab2/img/lab1-red.png?raw=1" alt="Diagrama de una neurona artificial" width="700"/>
#
# Completa la siguiente celda para calcular la salida de la red.

# %%
# Inicialización de pesos
np.random.seed(1234567) # Fijamos la semilla para que los números aleatorios salgan igual en cada ejecución para poder verificar los resultados

W0 = np.random.rand(5, x.shape[1]) - 0.5
b0 = np.random.rand(1,5) - 0.5

W1 = np.random.rand(3,5) - 0.5
b1 = np.random.rand(1,3) - 0.5

W2 = np.random.rand(1,3) - 0.5
b2 = np.random.rand(1,1) - 0.5


# Función auxiliar que utiliza la red neuronal para hacer una predicción
def calcula_prediccion(x):
    h0 = sigmoide(np.dot(x,W0.T)+b0)
    h1 = sigmoide(np.dot(h0,W1.T)+b1)
    y = sigmoide(np.dot(h1,W2.T)+b2)
    return y

# verificación
np.testing.assert_almost_equal(0.34535528, calcula_prediccion(x))

# %% [markdown]
# # Hacer predicciones con la red sobre un conjunto de datos
# Ahora que sabemos definir una red, probemos qué predicciones hace sobre un conjunto de datos. Cargaremos el conjunto `german_credit_numeric` de tensorflow_datasets, calcularemos la salida predicha para cada entrada y la compararemos con la etiqueta que se espera.

# %%
import tensorflow_datasets as tfds

# Cargamos el conjunto de datos
ds = tfds.load('german_credit_numeric', split='train')

W0 = np.random.rand(5, 24) - 0.5
b0 = np.random.rand(1, 5)


# Función auxiliar que, dada una lista de vectores de entrada, calcula la tasa de aciertos de la red
def calcula_tasa_aciertos(ejemplos):
    num_aciertos = 0
    num_elems = 0
    for ej in ejemplos:
        x = tfds.as_numpy(ej["features"])
        label = tfds.as_numpy(ej["label"])
        y_pred = calcula_prediccion(x)

        # Actualizamos los contadores de elementos y de aciertos
        num_elems += 1
        if ((y_pred > 0.5) and (label==1)) or ((y_pred <= 0.5) and (label==0)):
            num_aciertos += 1

    return num_aciertos / float(num_elems)

print('La tasa de acierto es del', calcula_tasa_aciertos(ds.take(100)))
# Out:
# La tasa de acierto es del 0.27

# %% [markdown]
# Previsiblemente, la red no funciona bien dado que las matrices de pesos contienen vectores aleatorios. Para que las predicciones mejoren, tenemos que ajustar nuestro modelo al conjunto de datos, es decir, encontrar valores para los parámetros ($\mathbf{W_0}$, $\mathbf{b_0}$, $\mathbf{W_1}$, $\mathbf{b_1}$, $\mathbf{W_2}$, $\mathbf{b_2}$) que arrojen buenas predicciones.

# %% [markdown]
# # Entrenamiento de la red
#
# ## La función de coste
# Para entrenar la red utilizaremos un proceso de optimización. En primer lugar, debemos definir qué función queremos optimizar. Necesitamos una función que, dada una combinación de parámetros de la red, devuelva un valor alto cuando las predicciones con esos parámetros sean malas y un valor bajo cuando estas sean buenas. Esto es lo que denominamos la **función de coste** ($J$). Definiremos una **función de pérdida** ($\mathcal{L}$) que reciba como entrada una predicción y una etiqueta real y nos indique cómo de desacertada es la predicción. En este caso utilizaremos la entropía cruzada binaria, descrita como:
#
# $$\mathcal{L}(y_{pred},y_{etiqueta}) = - y_{etiqueta} \log(y_{pred}) - (1-y_{etiqueta})  \log(1-y_{pred})$$
#
# La función de coste ($J$) será la media de la función de pérdida en los $m$ ejemplos del conjunto de entrenamiento:
# $$ J(\mathbf{W},\mathbf{b}) = \frac{1}{m} \sum_{i=1}^m \mathcal{L}(y_{pred}^{(i)}, y_{etiqueta}^{(i)})$$
#
# Si minimizamos $J$, nuestras predicciones serán mejores. Para minimizar $J$ utilizaremos **descenso de gradiente**: haremos sucesivos pasos en los que calcularemos el gradiente de $J$ respecto a los distintos parámetros ($\mathbf{W},\mathbf{b}$) y actualizaremos los parámetros en la dirección del gradiente, con la esperanza de que el siguiente paso obtenga un valor de $J$ menor. Repetiremos este proceso durante un número fijo de pasos.
#
# Por tanto, el algoritmo que debemos aplicar es el siguiente:
#  1. Calcular la pérdida de las predicciones con los valores actuales de $\mathbf{W}$ y $\mathbf{b}$
#  1. Calcular el gradiente respecto $\mathbf{W}$ y $\mathbf{b}$.
#  1. Actualizar $\mathbf{W}$ y $\mathbf{b}$ en la dirección de sus gradientes respectivos.
#
# ## Gradientes
# El segundo paso nos obliga a ser capaces de calcular el gradiente de $J(\mathbf{W},\mathbf{b})$ respecto a cada uno de los parámetros, es decir, la derivada parcial de $J(\mathbf{W},\mathbf{b})$ respecto a cada parámetro. Para ello iremos propagando el gradiente hacia atrás, calculando a cada paso el gradiente en el nodo anterior a partir de los posteriores. Calculemos, por ejemplo, el gradiente de $J(\mathbf{W},\mathbf{b})$ respecto a $z_2$:
#
# $$ \frac{\partial J(\mathbf{W},\mathbf{b})}{\partial z_2} = \frac{\partial (\frac{1}{m} \sum_{i=1}^m \mathcal{L}(y_{pred}^{(i)}, y_{etiqueta}^{(i)}))}{\partial z_2} = \frac{1}{m} \sum_{i=1}^m \frac{\partial \mathcal{L}(y_{pred}^{(i)}, y_{etiqueta}^{(i)})}{\partial z_2} $$
#
# Aplicando la regla de la cadena ([ver el desarrollo completo](./lab2-gradientes.pdf)) obtenemos las siguientes fórmulas para los gradientes:
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial b_2} = \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial z_2}$$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial W_2} = \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial z_2} h_1^T $$.
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial h_1} = \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial z_2} W_2^T $$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial z_1} = \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial h_1} h_1 (1 - h_1) = dLdz1$$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial b_1} = \sum_{i=1}^{5} dJdz1_i $$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial W_1} = diag(dLdz1) h_0^T $$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial h_0} = diag(dLdz1) W_1 $$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial z0} = \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial h_0} h_0 (1 - h_0) = dLdz0$$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial b_0} = \sum_{i=1}^{5} dLdz0_i $$
#
# $$ \frac{\partial \mathcal{L}(y_{pred}, y_{etiqueta})}{\partial W_0} = diag(dLdz0) x^T $$
#
# Conociendo estas fórmulas podemos adaptar nuestra función para que, además de calcular la predicción, devuelva los gradientes de la función de pérdida respecto a las variables involucradas.

# %%
def calcula_y_propaga(x, y_etiqueta):
    ''' Devuelve la salida predicha y, el valor de la función de pérdida y un diccionario con los gradientes de las variables
    '''
    x = x.reshape((1,24))

    # Cálculo de la salida
    z0 = np.dot(x,W0.T) + b0
    h0 = sigmoide(z0)
    z1 = np.dot(h0,W1.T) + b1
    h1 = sigmoide(z1)
    z2 = np.dot(h1,W2.T) + b2
    y = sigmoide(z2)

    #Backpropagation
    dLdz2 = y - y_etiqueta
    dLdb2 = dLdz2
    dLdW2 = dLdz2 * h1
    dLdh1 = np.matmul(dLdz2.T, W2)
    dLdz1 = dLdh1 * h1 * (1 - h1)
    dLdb1 = dLdz1
    dLdW1 = np.matmul(dLdz1.T, h0)
    dLdh0 = np.matmul(dLdz1, W1)
    dLdz0 = dLdh0 * h0 * (1 - h0)
    dLdb0 = dLdz0
    dLdW0 = np.matmul(dLdz0.T, x)

    # Los gradientes tienen que tener la misma forma que las variables respecto a las que se toman
    assert(dLdz2.shape==z2.shape)
    assert(dLdb2.shape==b2.shape)
    assert(dLdW2.shape==W2.shape)
    assert(dLdh1.shape==h1.shape)
    assert(dLdz1.shape==z1.shape)
    assert(dLdb1.shape==b1.shape)
    assert(dLdW1.shape==W1.shape)
    assert(dLdh0.shape==h0.shape)
    assert(dLdz0.shape==z0.shape)
    assert(dLdb0.shape==b0.shape)
    assert(dLdW0.shape==W0.shape)

    # Preparación del diccionario de gradientes
    gradientes = {}
    gradientes["b2"] = dLdb2
    gradientes["b1"] = dLdb1
    gradientes["b0"] = dLdb0
    gradientes["W2"] = dLdW2
    gradientes["W1"] = dLdW1
    gradientes["W0"] = dLdW0

    # Pérdida
    perdida = - y_etiqueta * np.log(y) - (1 - y_etiqueta) * np.log(1 - y)
    return y, perdida.flatten(), gradientes

# verificación
for elem in ds.take(1):
    prediccion, perdida, gradientes = calcula_y_propaga(elem["features"].numpy(), elem["label"].numpy())
    np.testing.assert_almost_equal(0.34011586, prediccion[0])
    np.testing.assert_almost_equal(1.07846895, perdida[0])

# %% [markdown]
# ## Bucle de aprendizaje
# Una vez podemos calcular los gradientes respecto a las variables para cada ejemplo del conjunto de entrenamiento ya podemos implementar el bucle de entrenamiento.
#
# Completa esta función para que realice `num_pasos` de entrenamiento en los cuales se haga lo siguiente:
#  1. Calcular las predicciones, pérdidas y gradientes para cada elemento del conjunto de entrenamiento
#  1. Calcular el valor promedio de cada gradiente
#  1. Utilizar dichos promedios para actualizar las variables
# Llevaremos también cuenta de la tasa de aciertos y del valor de la función de coste a cada paso.

# %%
def entrena(ejemplos, etiquetas, num_pasos, learning_rate = 0.001):
    paso = 0
    while paso < num_pasos:
        num_aciertos = 0
        num_elems = 0
        perdida_total = 0
        for x, label in zip(ejemplos, etiquetas):

            y_pred, perdida, gradientes = calcula_y_propaga(x, label)

            # Actualizamos los contadores de elementos y de aciertos
            num_elems += 1
            if ((y_pred > 0.5) and (label==1)) or ((y_pred <= 0.5) and (label==0)):
                num_aciertos += 1

            # Actualizamos el acumulador de la pérdida_total
            perdida_total += perdida

            # Actualizamos las variables en la dirección de su gradiente
            global W2, W1, W0, b2, b1, b0

            W2 = W2 - learning_rate * gradientes['W2']
            W1 = W1 - learning_rate * gradientes['W1']
            W0 = W0 - learning_rate * gradientes['W0']
            b2 = b2 - learning_rate * gradientes['b2']
            b1 = b1 - learning_rate * gradientes['b1']
            b0 = b0 - learning_rate * gradientes['b0']

        tasa_aciertos = num_aciertos / float(num_elems)
        perdida = perdida_total / float(num_elems)
        print(f'Epoch: {paso}/{num_pasos}: Pérdida: {perdida} Aciertos: {tasa_aciertos}')
        paso += 1

# %% [markdown]
# Para probar nuestro algoritmo de entrenamiento, tomemos solo los 100 primeros elementos del conjunto de datos y entrenemos el modelo para que se ajuste a dichos datos.

# %%
tamano_lote = 100
elems = ds.batch(tamano_lote)
lote_entrenamiento = None
for elem in elems:
    lote_entrenamiento = elem
    break
vectores_x = tfds.as_numpy(tf.cast(lote_entrenamiento["features"],dtype=tf.float64))
etiquetas = tfds.as_numpy(tf.cast(lote_entrenamiento["label"],dtype=tf.float64))

entrena(vectores_x, etiquetas, 5000)
# Out:
# Epoch: 0/5000: Pérdida: [0.8828747] Aciertos: 0.27
# Epoch: 1/5000: Pérdida: [0.85456337] Aciertos: 0.27
# Epoch: 2/5000: Pérdida: [0.82891753] Aciertos: 0.27
# Epoch: 3/5000: Pérdida: [0.80571908] Aciertos: 0.27
# Epoch: 4/5000: Pérdida: [0.78476001] Aciertos: 0.27
# Epoch: 5/5000: Pérdida: [0.76584115] Aciertos: 0.27
# Epoch: 6/5000: Pérdida: [0.74877282] Aciertos: 0.27
# Epoch: 7/5000: Pérdida: [0.73337657] Aciertos: 0.27
# Epoch: 8/5000: Pérdida: [0.71948693] Aciertos: 0.27
# Epoch: 9/5000: Pérdida: [0.70695242] Aciertos: 0.27
# Epoch: 10/5000: Pérdida: [0.69563581] Aciertos: 0.47
# Epoch: 11/5000: Pérdida: [0.68541355] Aciertos: 0.68
# Epoch: 12/5000: Pérdida: [0.6761748] Aciertos: 0.73
# Epoch: 13/5000: Pérdida: [0.66782031] Aciertos: 0.73
# Epoch: 14/5000: Pérdida: [0.66026121] Aciertos: 0.73
# Epoch: 15/5000: Pérdida: [0.65341794] Aciertos: 0.73
# Epoch: 16/5000: Pérdida: [0.64721925] Aciertos: 0.73
# Epoch: 17/5000: Pérdida: [0.64160128] Aciertos: 0.73
# Epoch: 18/5000: Pérdida: [0.63650681] Aciertos: 0.73
# Epoch: 19/5000: Pérdida: [0.63188451] Aciertos: 0.73
# Epoch: 20/5000: Pérdida: [0.62768832] Aciertos: 0.73
# Epoch: 21/5000: Pérdida: [0.6238769] Aciertos: 0.73
# Epoch: 22/5000: Pérdida: [0.62041311] Aciertos: 0.73
# Epoch: 23/5000: Pérdida: [0.61726357] Aciertos: 0.73
# Epoch: 24/5000: Pérdida: [0.61439826] Aciertos: 0.73
# Epoch: 25/5000: Pérdida: [0.61179018] Aciertos: 0.73
# Epoch: 26/5000: Pérdida: [0.60941502] Aciertos: 0.73
# Epoch: 27/5000: Pérdida: [0.60725087] Aciertos: 0.73
# Epoch: 28/5000: Pérdida: [0.60527798] Aciertos: 0.73
# Epoch: 29/5000: Pérdida: [0.60347853] Aciertos: 0.73
# Epoch: 30/5000: Pérdida: [0.60183645] Aciertos: 0.73
# Epoch: 31/5000: Pérdida: [0.6003372] Aciertos: 0.73
# Epoch: 32/5000: Pérdida: [0.59896763] Aciertos: 0.73
# Epoch: 33/5000: Pérdida: [0.59771586] Aciertos: 0.73
# Epoch: 34/5000: Pérdida: [0.59657114] Aciertos: 0.73
# Epoch: 35/5000: Pérdida: [0.59552372] Aciertos: 0.73
# Epoch: 36/5000: Pérdida: [0.59456478] Aciertos: 0.73
# Epoch: 37/5000: Pérdida: [0.59368631] Aciertos: 0.73
# Epoch: 38/5000: Pérdida: [0.59288109] Aciertos: 0.73
# Epoch: 39/5000: Pérdida: [0.59214254] Aciertos: 0.73
# Epoch: 40/5000: Pérdida: [0.59146472] Aciertos: 0.73
# Epoch: 41/5000: Pérdida: [0.59084223] Aciertos: 0.73
# Epoch: 42/5000: Pérdida: [0.59027019] Aciertos: 0.73
# Epoch: 43/5000: Pérdida: [0.58974416] Aciertos: 0.73
# Epoch: 44/5000: Pérdida: [0.58926013] Aciertos: 0.73
# Epoch: 45/5000: Pérdida: [0.58881444] Aciertos: 0.73
# Epoch: 46/5000: Pérdida: [0.58840378] Aciertos: 0.73
# Epoch: 47/5000: Pérdida: [0.58802512] Aciertos: 0.73
# Epoch: 48/5000: Pérdida: [0.58767571] Aciertos: 0.73
# Epoch: 49/5000: Pérdida: [0.58735305] Aciertos: 0.73
# Epoch: 50/5000: Pérdida: [0.58705483] Aciertos: 0.73
# Epoch: 51/5000: Pérdida: [0.58677897] Aciertos: 0.73
# Epoch: 52/5000: Pérdida: [0.58652355] Aciertos: 0.73
# Epoch: 53/5000: Pérdida: [0.58628681] Aciertos: 0.73
# Epoch: 54/5000: Pérdida: [0.58606713] Aciertos: 0.73
# Epoch: 55/5000: Pérdida: [0.58586305] Aciertos: 0.73
# Epoch: 56/5000: Pérdida: [0.5856732] Aciertos: 0.73
# Epoch: 57/5000: Pérdida: [0.58549634] Aciertos: 0.73
# Epoch: 58/5000: Pérdida: [0.58533134] Aciertos: 0.73
# Epoch: 59/5000: Pérdida: [0.58517714] Aciertos: 0.73
# Epoch: 60/5000: Pérdida: [0.58503277] Aciertos: 0.73
# Epoch: 61/5000: Pérdida: [0.58489737] Aciertos: 0.73
# Epoch: 62/5000: Pérdida: [0.58477011] Aciertos: 0.73
# Epoch: 63/5000: Pérdida: [0.58465026] Aciertos: 0.73
# Epoch: 64/5000: Pérdida: [0.58453711] Aciertos: 0.73
# Epoch: 65/5000: Pérdida: [0.58443006] Aciertos: 0.73
# Epoch: 66/5000: Pérdida: [0.58432852] Aciertos: 0.73
# Epoch: 67/5000: Pérdida: [0.58423195] Aciertos: 0.73
# Epoch: 68/5000: Pérdida: [0.58413988] Aciertos: 0.73
# Epoch: 69/5000: Pérdida: [0.58405186] Aciertos: 0.73
# Epoch: 70/5000: Pérdida: [0.58396748] Aciertos: 0.73
# Epoch: 71/5000: Pérdida: [0.58388637] Aciertos: 0.73
# Epoch: 72/5000: Pérdida: [0.5838082] Aciertos: 0.73
# Epoch: 73/5000: Pérdida: [0.58373265] Aciertos: 0.73
# Epoch: 74/5000: Pérdida: [0.58365945] Aciertos: 0.73
# Epoch: 75/5000: Pérdida: [0.58358835] Aciertos: 0.73
# Epoch: 76/5000: Pérdida: [0.58351914] Aciertos: 0.73
# Epoch: 77/5000: Pérdida: [0.58345164] Aciertos: 0.73
# Epoch: 78/5000: Pérdida: [0.58338568] Aciertos: 0.73
# Epoch: 79/5000: Pérdida: [0.58332113] Aciertos: 0.73
# Epoch: 80/5000: Pérdida: [0.58325792] Aciertos: 0.73
# Epoch: 81/5000: Pérdida: [0.58319595] Aciertos: 0.73
# Epoch: 82/5000: Pérdida: [0.58313521] Aciertos: 0.73
# Epoch: 83/5000: Pérdida: [0.58307568] Aciertos: 0.73
# Epoch: 84/5000: Pérdida: [0.58301738] Aciertos: 0.73
# Epoch: 85/5000: Pérdida: [0.58296035] Aciertos: 0.73
# Epoch: 86/5000: Pérdida: [0.58290463] Aciertos: 0.73
# Epoch: 87/5000: Pérdida: [0.58285029] Aciertos: 0.73
# Epoch: 88/5000: Pérdida: [0.5827974] Aciertos: 0.73
# Epoch: 89/5000: Pérdida: [0.58274603] Aciertos: 0.73
# Epoch: 90/5000: Pérdida: [0.58269623] Aciertos: 0.73
# Epoch: 91/5000: Pérdida: [0.58264805] Aciertos: 0.73
# Epoch: 92/5000: Pérdida: [0.58260152] Aciertos: 0.73
# Epoch: 93/5000: Pérdida: [0.58255666] Aciertos: 0.73
# Epoch: 94/5000: Pérdida: [0.58251345] Aciertos: 0.73
# Epoch: 95/5000: Pérdida: [0.58247189] Aciertos: 0.73
# Epoch: 96/5000: Pérdida: [0.58243194] Aciertos: 0.73
# Epoch: 97/5000: Pérdida: [0.58239356] Aciertos: 0.73
# Epoch: 98/5000: Pérdida: [0.58235668] Aciertos: 0.73
# Epoch: 99/5000: Pérdida: [0.58232125] Aciertos: 0.73
# Epoch: 100/5000: Pérdida: [0.58228719] Aciertos: 0.73
# Epoch: 101/5000: Pérdida: [0.58225444] Aciertos: 0.73
# Epoch: 102/5000: Pérdida: [0.58222292] Aciertos: 0.73
# Epoch: 103/5000: Pérdida: [0.58219255] Aciertos: 0.73
# Epoch: 104/5000: Pérdida: [0.58216326] Aciertos: 0.73
# Epoch: 105/5000: Pérdida: [0.58213498] Aciertos: 0.73
# Epoch: 106/5000: Pérdida: [0.58210763] Aciertos: 0.73
# Epoch: 107/5000: Pérdida: [0.58208116] Aciertos: 0.73
# Epoch: 108/5000: Pérdida: [0.5820555] Aciertos: 0.73
# Epoch: 109/5000: Pérdida: [0.58203059] Aciertos: 0.73
# Epoch: 110/5000: Pérdida: [0.58200637] Aciertos: 0.73
# Epoch: 111/5000: Pérdida: [0.58198279] Aciertos: 0.73
# Epoch: 112/5000: Pérdida: [0.5819598] Aciertos: 0.73
# Epoch: 113/5000: Pérdida: [0.58193736] Aciertos: 0.73
# Epoch: 114/5000: Pérdida: [0.58191542] Aciertos: 0.73
# Epoch: 115/5000: Pérdida: [0.58189395] Aciertos: 0.73
# Epoch: 116/5000: Pérdida: [0.58187291] Aciertos: 0.73
# Epoch: 117/5000: Pérdida: [0.58185226] Aciertos: 0.73
# Epoch: 118/5000: Pérdida: [0.58183198] Aciertos: 0.73
# Epoch: 119/5000: Pérdida: [0.58181204] Aciertos: 0.73
# Epoch: 120/5000: Pérdida: [0.58179241] Aciertos: 0.73
# Epoch: 121/5000: Pérdida: [0.58177306] Aciertos: 0.73
# Epoch: 122/5000: Pérdida: [0.58175399] Aciertos: 0.73
# Epoch: 123/5000: Pérdida: [0.58173515] Aciertos: 0.73
# Epoch: 124/5000: Pérdida: [0.58171655] Aciertos: 0.73
# Epoch: 125/5000: Pérdida: [0.58169816] Aciertos: 0.73
# Epoch: 126/5000: Pérdida: [0.58167996] Aciertos: 0.73
# Epoch: 127/5000: Pérdida: [0.58166194] Aciertos: 0.73
# Epoch: 128/5000: Pérdida: [0.5816441] Aciertos: 0.73
# Epoch: 129/5000: Pérdida: [0.5816264] Aciertos: 0.73
# Epoch: 130/5000: Pérdida: [0.58160886] Aciertos: 0.73
# Epoch: 131/5000: Pérdida: [0.58159145] Aciertos: 0.73
# Epoch: 132/5000: Pérdida: [0.58157416] Aciertos: 0.73
# Epoch: 133/5000: Pérdida: [0.58155699] Aciertos: 0.73
# Epoch: 134/5000: Pérdida: [0.58153993] Aciertos: 0.73
# Epoch: 135/5000: Pérdida: [0.58152297] Aciertos: 0.73
# Epoch: 136/5000: Pérdida: [0.58150611] Aciertos: 0.73
# Epoch: 137/5000: Pérdida: [0.58148933] Aciertos: 0.73
# Epoch: 138/5000: Pérdida: [0.58147264] Aciertos: 0.73
# Epoch: 139/5000: Pérdida: [0.58145603] Aciertos: 0.73
# Epoch: 140/5000: Pérdida: [0.58143949] Aciertos: 0.73
# Epoch: 141/5000: Pérdida: [0.58142302] Aciertos: 0.73
# Epoch: 142/5000: Pérdida: [0.58140661] Aciertos: 0.73
# Epoch: 143/5000: Pérdida: [0.58139026] Aciertos: 0.73
# Epoch: 144/5000: Pérdida: [0.58137397] Aciertos: 0.73
# Epoch: 145/5000: Pérdida: [0.58135773] Aciertos: 0.73
# Epoch: 146/5000: Pérdida: [0.58134154] Aciertos: 0.73
# Epoch: 147/5000: Pérdida: [0.5813254] Aciertos: 0.73
# Epoch: 148/5000: Pérdida: [0.5813093] Aciertos: 0.73
# Epoch: 149/5000: Pérdida: [0.58129324] Aciertos: 0.73
# Epoch: 150/5000: Pérdida: [0.58127722] Aciertos: 0.73
# Epoch: 151/5000: Pérdida: [0.58126124] Aciertos: 0.73
# Epoch: 152/5000: Pérdida: [0.58124528] Aciertos: 0.73
# Epoch: 153/5000: Pérdida: [0.58122936] Aciertos: 0.73
# Epoch: 154/5000: Pérdida: [0.58121347] Aciertos: 0.73
# Epoch: 155/5000: Pérdida: [0.58119761] Aciertos: 0.73
# Epoch: 156/5000: Pérdida: [0.58118176] Aciertos: 0.73
# Epoch: 157/5000: Pérdida: [0.58116594] Aciertos: 0.73
# Epoch: 158/5000: Pérdida: [0.58115014] Aciertos: 0.73
# Epoch: 159/5000: Pérdida: [0.58113436] Aciertos: 0.73
# Epoch: 160/5000: Pérdida: [0.58111859] Aciertos: 0.73
# Epoch: 161/5000: Pérdida: [0.58110284] Aciertos: 0.73
# Epoch: 162/5000: Pérdida: [0.58108709] Aciertos: 0.73
# Epoch: 163/5000: Pérdida: [0.58107136] Aciertos: 0.73
# Epoch: 164/5000: Pérdida: [0.58105562] Aciertos: 0.73
# Epoch: 165/5000: Pérdida: [0.5810399] Aciertos: 0.73
# Epoch: 166/5000: Pérdida: [0.58102417] Aciertos: 0.73
# Epoch: 167/5000: Pérdida: [0.58100844] Aciertos: 0.73
# Epoch: 168/5000: Pérdida: [0.5809927] Aciertos: 0.73
# Epoch: 169/5000: Pérdida: [0.58097696] Aciertos: 0.73
# Epoch: 170/5000: Pérdida: [0.5809612] Aciertos: 0.73
# Epoch: 171/5000: Pérdida: [0.58094543] Aciertos: 0.73
# Epoch: 172/5000: Pérdida: [0.58092964] Aciertos: 0.73
# Epoch: 173/5000: Pérdida: [0.58091383] Aciertos: 0.73
# Epoch: 174/5000: Pérdida: [0.58089799] Aciertos: 0.73
# Epoch: 175/5000: Pérdida: [0.58088212] Aciertos: 0.73
# Epoch: 176/5000: Pérdida: [0.58086622] Aciertos: 0.73
# Epoch: 177/5000: Pérdida: [0.58085028] Aciertos: 0.73
# Epoch: 178/5000: Pérdida: [0.58083429] Aciertos: 0.73
# Epoch: 179/5000: Pérdida: [0.58081825] Aciertos: 0.73
# Epoch: 180/5000: Pérdida: [0.58080216] Aciertos: 0.73
# Epoch: 181/5000: Pérdida: [0.58078601] Aciertos: 0.73
# Epoch: 182/5000: Pérdida: [0.58076979] Aciertos: 0.73
# Epoch: 183/5000: Pérdida: [0.58075351] Aciertos: 0.73
# Epoch: 184/5000: Pérdida: [0.58073715] Aciertos: 0.73
# Epoch: 185/5000: Pérdida: [0.5807207] Aciertos: 0.73
# Epoch: 186/5000: Pérdida: [0.58070417] Aciertos: 0.73
# Epoch: 187/5000: Pérdida: [0.58068755] Aciertos: 0.73
# Epoch: 188/5000: Pérdida: [0.58067084] Aciertos: 0.73
# Epoch: 189/5000: Pérdida: [0.58065403] Aciertos: 0.73
# Epoch: 190/5000: Pérdida: [0.58063711] Aciertos: 0.73
# Epoch: 191/5000: Pérdida: [0.5806201] Aciertos: 0.73
# Epoch: 192/5000: Pérdida: [0.58060298] Aciertos: 0.73
# Epoch: 193/5000: Pérdida: [0.58058577] Aciertos: 0.73
# Epoch: 194/5000: Pérdida: [0.58056845] Aciertos: 0.73
# Epoch: 195/5000: Pérdida: [0.58055105] Aciertos: 0.73
# Epoch: 196/5000: Pérdida: [0.58053356] Aciertos: 0.73
# Epoch: 197/5000: Pérdida: [0.58051599] Aciertos: 0.73
# Epoch: 198/5000: Pérdida: [0.58049836] Aciertos: 0.73
# Epoch: 199/5000: Pérdida: [0.58048067] Aciertos: 0.73
# Epoch: 200/5000: Pérdida: [0.58046295] Aciertos: 0.73
# Epoch: 201/5000: Pérdida: [0.58044521] Aciertos: 0.73
# Epoch: 202/5000: Pérdida: [0.58042747] Aciertos: 0.73
# Epoch: 203/5000: Pérdida: [0.58040975] Aciertos: 0.73
# Epoch: 204/5000: Pérdida: [0.58039206] Aciertos: 0.73
# Epoch: 205/5000: Pérdida: [0.58037442] Aciertos: 0.73
# Epoch: 206/5000: Pérdida: [0.58035686] Aciertos: 0.73
# Epoch: 207/5000: Pérdida: [0.58033938] Aciertos: 0.73
# Epoch: 208/5000: Pérdida: [0.580322] Aciertos: 0.73
# Epoch: 209/5000: Pérdida: [0.58030474] Aciertos: 0.73
# Epoch: 210/5000: Pérdida: [0.58028759] Aciertos: 0.73
# Epoch: 211/5000: Pérdida: [0.58027057] Aciertos: 0.73
# Epoch: 212/5000: Pérdida: [0.58025368] Aciertos: 0.73
# Epoch: 213/5000: Pérdida: [0.58023692] Aciertos: 0.73
# Epoch: 214/5000: Pérdida: [0.58022029] Aciertos: 0.73
# Epoch: 215/5000: Pérdida: [0.58020379] Aciertos: 0.73
# Epoch: 216/5000: Pérdida: [0.5801874] Aciertos: 0.73
# Epoch: 217/5000: Pérdida: [0.58017114] Aciertos: 0.73
# Epoch: 218/5000: Pérdida: [0.58015498] Aciertos: 0.73
# Epoch: 219/5000: Pérdida: [0.58013892] Aciertos: 0.73
# Epoch: 220/5000: Pérdida: [0.58012295] Aciertos: 0.73
# Epoch: 221/5000: Pérdida: [0.58010706] Aciertos: 0.73
# Epoch: 222/5000: Pérdida: [0.58009125] Aciertos: 0.73
# Epoch: 223/5000: Pérdida: [0.58007549] Aciertos: 0.73
# Epoch: 224/5000: Pérdida: [0.58005979] Aciertos: 0.73
# Epoch: 225/5000: Pérdida: [0.58004413] Aciertos: 0.73
# Epoch: 226/5000: Pérdida: [0.5800285] Aciertos: 0.73
# Epoch: 227/5000: Pérdida: [0.58001289] Aciertos: 0.73
# Epoch: 228/5000: Pérdida: [0.5799973] Aciertos: 0.73
# Epoch: 229/5000: Pérdida: [0.5799817] Aciertos: 0.73
# Epoch: 230/5000: Pérdida: [0.5799661] Aciertos: 0.73
# Epoch: 231/5000: Pérdida: [0.57995049] Aciertos: 0.73
# Epoch: 232/5000: Pérdida: [0.57993484] Aciertos: 0.73
# Epoch: 233/5000: Pérdida: [0.57991917] Aciertos: 0.73
# Epoch: 234/5000: Pérdida: [0.57990345] Aciertos: 0.73
# Epoch: 235/5000: Pérdida: [0.57988767] Aciertos: 0.73
# Epoch: 236/5000: Pérdida: [0.57987184] Aciertos: 0.73
# Epoch: 237/5000: Pérdida: [0.57985593] Aciertos: 0.73
# Epoch: 238/5000: Pérdida: [0.57983995] Aciertos: 0.73
# Epoch: 239/5000: Pérdida: [0.57982388] Aciertos: 0.73
# Epoch: 240/5000: Pérdida: [0.57980771] Aciertos: 0.73
# Epoch: 241/5000: Pérdida: [0.57979145] Aciertos: 0.73
# Epoch: 242/5000: Pérdida: [0.57977507] Aciertos: 0.73
# Epoch: 243/5000: Pérdida: [0.57975858] Aciertos: 0.73
# Epoch: 244/5000: Pérdida: [0.57974197] Aciertos: 0.73
# Epoch: 245/5000: Pérdida: [0.57972523] Aciertos: 0.73
# Epoch: 246/5000: Pérdida: [0.57970836] Aciertos: 0.73
# Epoch: 247/5000: Pérdida: [0.57969137] Aciertos: 0.73
# Epoch: 248/5000: Pérdida: [0.57967424] Aciertos: 0.73
# Epoch: 249/5000: Pérdida: [0.57965698] Aciertos: 0.73
# Epoch: 250/5000: Pérdida: [0.5796396] Aciertos: 0.73
# Epoch: 251/5000: Pérdida: [0.5796221] Aciertos: 0.73
# Epoch: 252/5000: Pérdida: [0.57960448] Aciertos: 0.73
# Epoch: 253/5000: Pérdida: [0.57958676] Aciertos: 0.73
# Epoch: 254/5000: Pérdida: [0.57956894] Aciertos: 0.73
# Epoch: 255/5000: Pérdida: [0.57955105] Aciertos: 0.73
# Epoch: 256/5000: Pérdida: [0.57953309] Aciertos: 0.73
# Epoch: 257/5000: Pérdida: [0.57951507] Aciertos: 0.73
# Epoch: 258/5000: Pérdida: [0.57949702] Aciertos: 0.73
# Epoch: 259/5000: Pérdida: [0.57947895] Aciertos: 0.73
# Epoch: 260/5000: Pérdida: [0.57946088] Aciertos: 0.73
# Epoch: 261/5000: Pérdida: [0.57944282] Aciertos: 0.73
# Epoch: 262/5000: Pérdida: [0.57942478] Aciertos: 0.73
# Epoch: 263/5000: Pérdida: [0.57940677] Aciertos: 0.73
# Epoch: 264/5000: Pérdida: [0.57938882] Aciertos: 0.73
# Epoch: 265/5000: Pérdida: [0.57937092] Aciertos: 0.73
# Epoch: 266/5000: Pérdida: [0.57935309] Aciertos: 0.73
# Epoch: 267/5000: Pérdida: [0.57933532] Aciertos: 0.73
# Epoch: 268/5000: Pérdida: [0.57931763] Aciertos: 0.73
# Epoch: 269/5000: Pérdida: [0.57930001] Aciertos: 0.73
# Epoch: 270/5000: Pérdida: [0.57928247] Aciertos: 0.73
# Epoch: 271/5000: Pérdida: [0.579265] Aciertos: 0.73
# Epoch: 272/5000: Pérdida: [0.57924761] Aciertos: 0.73
# Epoch: 273/5000: Pérdida: [0.57923028] Aciertos: 0.73
# Epoch: 274/5000: Pérdida: [0.57921303] Aciertos: 0.73
# Epoch: 275/5000: Pérdida: [0.57919584] Aciertos: 0.73
# Epoch: 276/5000: Pérdida: [0.57917871] Aciertos: 0.73
# Epoch: 277/5000: Pérdida: [0.57916164] Aciertos: 0.73
# Epoch: 278/5000: Pérdida: [0.57914462] Aciertos: 0.73
# Epoch: 279/5000: Pérdida: [0.57912764] Aciertos: 0.73
# Epoch: 280/5000: Pérdida: [0.57911071] Aciertos: 0.73
# Epoch: 281/5000: Pérdida: [0.57909381] Aciertos: 0.73
# Epoch: 282/5000: Pérdida: [0.57907695] Aciertos: 0.73
# Epoch: 283/5000: Pérdida: [0.57906011] Aciertos: 0.73
# Epoch: 284/5000: Pérdida: [0.5790433] Aciertos: 0.73
# Epoch: 285/5000: Pérdida: [0.57902651] Aciertos: 0.73
# Epoch: 286/5000: Pérdida: [0.57900974] Aciertos: 0.73
# Epoch: 287/5000: Pérdida: [0.57899298] Aciertos: 0.73
# Epoch: 288/5000: Pérdida: [0.57897622] Aciertos: 0.73
# Epoch: 289/5000: Pérdida: [0.57895947] Aciertos: 0.73
# Epoch: 290/5000: Pérdida: [0.57894272] Aciertos: 0.73
# Epoch: 291/5000: Pérdida: [0.57892598] Aciertos: 0.73
# Epoch: 292/5000: Pérdida: [0.57890922] Aciertos: 0.73
# Epoch: 293/5000: Pérdida: [0.57889246] Aciertos: 0.73
# Epoch: 294/5000: Pérdida: [0.57887569] Aciertos: 0.73
# Epoch: 295/5000: Pérdida: [0.57885891] Aciertos: 0.73
# Epoch: 296/5000: Pérdida: [0.57884211] Aciertos: 0.73
# Epoch: 297/5000: Pérdida: [0.57882529] Aciertos: 0.73
# Epoch: 298/5000: Pérdida: [0.57880846] Aciertos: 0.73
# Epoch: 299/5000: Pérdida: [0.5787916] Aciertos: 0.73
# Epoch: 300/5000: Pérdida: [0.57877472] Aciertos: 0.73
# Epoch: 301/5000: Pérdida: [0.57875781] Aciertos: 0.73
# Epoch: 302/5000: Pérdida: [0.57874088] Aciertos: 0.73
# Epoch: 303/5000: Pérdida: [0.57872392] Aciertos: 0.73
# Epoch: 304/5000: Pérdida: [0.57870692] Aciertos: 0.73
# Epoch: 305/5000: Pérdida: [0.5786899] Aciertos: 0.73
# Epoch: 306/5000: Pérdida: [0.57867284] Aciertos: 0.73
# Epoch: 307/5000: Pérdida: [0.57865574] Aciertos: 0.73
# Epoch: 308/5000: Pérdida: [0.57863861] Aciertos: 0.73
# Epoch: 309/5000: Pérdida: [0.57862144] Aciertos: 0.73
# Epoch: 310/5000: Pérdida: [0.57860423] Aciertos: 0.73
# Epoch: 311/5000: Pérdida: [0.57858697] Aciertos: 0.73
# Epoch: 312/5000: Pérdida: [0.57856968] Aciertos: 0.73
# Epoch: 313/5000: Pérdida: [0.57855234] Aciertos: 0.73
# Epoch: 314/5000: Pérdida: [0.57853496] Aciertos: 0.73
# Epoch: 315/5000: Pérdida: [0.57851753] Aciertos: 0.73
# Epoch: 316/5000: Pérdida: [0.57850006] Aciertos: 0.73
# Epoch: 317/5000: Pérdida: [0.57848254] Aciertos: 0.73
# Epoch: 318/5000: Pérdida: [0.57846497] Aciertos: 0.73
# Epoch: 319/5000: Pérdida: [0.57844734] Aciertos: 0.73
# Epoch: 320/5000: Pérdida: [0.57842967] Aciertos: 0.73
# Epoch: 321/5000: Pérdida: [0.57841195] Aciertos: 0.73
# Epoch: 322/5000: Pérdida: [0.57839417] Aciertos: 0.73
# Epoch: 323/5000: Pérdida: [0.57837634] Aciertos: 0.73
# Epoch: 324/5000: Pérdida: [0.57835845] Aciertos: 0.73
# Epoch: 325/5000: Pérdida: [0.57834051] Aciertos: 0.73
# Epoch: 326/5000: Pérdida: [0.57832251] Aciertos: 0.73
# Epoch: 327/5000: Pérdida: [0.57830446] Aciertos: 0.73
# Epoch: 328/5000: Pérdida: [0.57828635] Aciertos: 0.73
# Epoch: 329/5000: Pérdida: [0.57826818] Aciertos: 0.73
# Epoch: 330/5000: Pérdida: [0.57824995] Aciertos: 0.73
# Epoch: 331/5000: Pérdida: [0.57823166] Aciertos: 0.73
# Epoch: 332/5000: Pérdida: [0.57821332] Aciertos: 0.73
# Epoch: 333/5000: Pérdida: [0.57819491] Aciertos: 0.73
# Epoch: 334/5000: Pérdida: [0.57817645] Aciertos: 0.73
# Epoch: 335/5000: Pérdida: [0.57815792] Aciertos: 0.73
# Epoch: 336/5000: Pérdida: [0.57813934] Aciertos: 0.73
# Epoch: 337/5000: Pérdida: [0.57812069] Aciertos: 0.73
# Epoch: 338/5000: Pérdida: [0.57810199] Aciertos: 0.73
# Epoch: 339/5000: Pérdida: [0.57808323] Aciertos: 0.73
# Epoch: 340/5000: Pérdida: [0.5780644] Aciertos: 0.73
# Epoch: 341/5000: Pérdida: [0.57804552] Aciertos: 0.73
# Epoch: 342/5000: Pérdida: [0.57802658] Aciertos: 0.73
# Epoch: 343/5000: Pérdida: [0.57800758] Aciertos: 0.73
# Epoch: 344/5000: Pérdida: [0.57798852] Aciertos: 0.73
# Epoch: 345/5000: Pérdida: [0.57796941] Aciertos: 0.73
# Epoch: 346/5000: Pérdida: [0.57795024] Aciertos: 0.73
# Epoch: 347/5000: Pérdida: [0.57793102] Aciertos: 0.73
# Epoch: 348/5000: Pérdida: [0.57791174] Aciertos: 0.73
# Epoch: 349/5000: Pérdida: [0.57789241] Aciertos: 0.73
# Epoch: 350/5000: Pérdida: [0.57787303] Aciertos: 0.73
# Epoch: 351/5000: Pérdida: [0.5778536] Aciertos: 0.73
# Epoch: 352/5000: Pérdida: [0.57783411] Aciertos: 0.73
# Epoch: 353/5000: Pérdida: [0.57781459] Aciertos: 0.73
# Epoch: 354/5000: Pérdida: [0.57779501] Aciertos: 0.73
# Epoch: 355/5000: Pérdida: [0.57777539] Aciertos: 0.73
# Epoch: 356/5000: Pérdida: [0.57775572] Aciertos: 0.73
# Epoch: 357/5000: Pérdida: [0.57773601] Aciertos: 0.73
# Epoch: 358/5000: Pérdida: [0.57771626] Aciertos: 0.73
# Epoch: 359/5000: Pérdida: [0.57769647] Aciertos: 0.73
# Epoch: 360/5000: Pérdida: [0.57767664] Aciertos: 0.73
# Epoch: 361/5000: Pérdida: [0.57765678] Aciertos: 0.73
# Epoch: 362/5000: Pérdida: [0.57763687] Aciertos: 0.73
# Epoch: 363/5000: Pérdida: [0.57761693] Aciertos: 0.73
# Epoch: 364/5000: Pérdida: [0.57759695] Aciertos: 0.73
# Epoch: 365/5000: Pérdida: [0.57757694] Aciertos: 0.73
# Epoch: 366/5000: Pérdida: [0.57755689] Aciertos: 0.73
# Epoch: 367/5000: Pérdida: [0.57753681] Aciertos: 0.73
# Epoch: 368/5000: Pérdida: [0.5775167] Aciertos: 0.73
# Epoch: 369/5000: Pérdida: [0.57749655] Aciertos: 0.73
# Epoch: 370/5000: Pérdida: [0.57747637] Aciertos: 0.73
# Epoch: 371/5000: Pérdida: [0.57745616] Aciertos: 0.73
# Epoch: 372/5000: Pérdida: [0.57743592] Aciertos: 0.73
# Epoch: 373/5000: Pérdida: [0.57741564] Aciertos: 0.73
# Epoch: 374/5000: Pérdida: [0.57739533] Aciertos: 0.73
# Epoch: 375/5000: Pérdida: [0.57737499] Aciertos: 0.73
# Epoch: 376/5000: Pérdida: [0.57735462] Aciertos: 0.73
# Epoch: 377/5000: Pérdida: [0.57733421] Aciertos: 0.73
# Epoch: 378/5000: Pérdida: [0.57731377] Aciertos: 0.73
# Epoch: 379/5000: Pérdida: [0.57729329] Aciertos: 0.73
# Epoch: 380/5000: Pérdida: [0.57727278] Aciertos: 0.73
# Epoch: 381/5000: Pérdida: [0.57725223] Aciertos: 0.73
# Epoch: 382/5000: Pérdida: [0.57723165] Aciertos: 0.73
# Epoch: 383/5000: Pérdida: [0.57721103] Aciertos: 0.73
# Epoch: 384/5000: Pérdida: [0.57719038] Aciertos: 0.73
# Epoch: 385/5000: Pérdida: [0.57716968] Aciertos: 0.73
# Epoch: 386/5000: Pérdida: [0.57714895] Aciertos: 0.73
# Epoch: 387/5000: Pérdida: [0.57712818] Aciertos: 0.73
# Epoch: 388/5000: Pérdida: [0.57710736] Aciertos: 0.73
# Epoch: 389/5000: Pérdida: [0.57708651] Aciertos: 0.73
# Epoch: 390/5000: Pérdida: [0.57706561] Aciertos: 0.73
# Epoch: 391/5000: Pérdida: [0.57704467] Aciertos: 0.73
# Epoch: 392/5000: Pérdida: [0.57702369] Aciertos: 0.73
# Epoch: 393/5000: Pérdida: [0.57700267] Aciertos: 0.73
# Epoch: 394/5000: Pérdida: [0.57698159] Aciertos: 0.73
# Epoch: 395/5000: Pérdida: [0.57696048] Aciertos: 0.73
# Epoch: 396/5000: Pérdida: [0.57693931] Aciertos: 0.73
# Epoch: 397/5000: Pérdida: [0.5769181] Aciertos: 0.73
# Epoch: 398/5000: Pérdida: [0.57689684] Aciertos: 0.73
# Epoch: 399/5000: Pérdida: [0.57687552] Aciertos: 0.73
# Epoch: 400/5000: Pérdida: [0.57685416] Aciertos: 0.73
# Epoch: 401/5000: Pérdida: [0.57683275] Aciertos: 0.73
# Epoch: 402/5000: Pérdida: [0.57681129] Aciertos: 0.73
# Epoch: 403/5000: Pérdida: [0.57678977] Aciertos: 0.73
# Epoch: 404/5000: Pérdida: [0.5767682] Aciertos: 0.73
# Epoch: 405/5000: Pérdida: [0.57674658] Aciertos: 0.73
# Epoch: 406/5000: Pérdida: [0.5767249] Aciertos: 0.73
# Epoch: 407/5000: Pérdida: [0.57670317] Aciertos: 0.73
# Epoch: 408/5000: Pérdida: [0.57668138] Aciertos: 0.73
# Epoch: 409/5000: Pérdida: [0.57665953] Aciertos: 0.73
# Epoch: 410/5000: Pérdida: [0.57663762] Aciertos: 0.73
# Epoch: 411/5000: Pérdida: [0.57661566] Aciertos: 0.73
# Epoch: 412/5000: Pérdida: [0.57659364] Aciertos: 0.73
# Epoch: 413/5000: Pérdida: [0.57657156] Aciertos: 0.73
# Epoch: 414/5000: Pérdida: [0.57654942] Aciertos: 0.73
# Epoch: 415/5000: Pérdida: [0.57652722] Aciertos: 0.73
# Epoch: 416/5000: Pérdida: [0.57650496] Aciertos: 0.73
# Epoch: 417/5000: Pérdida: [0.57648263] Aciertos: 0.73
# Epoch: 418/5000: Pérdida: [0.57646025] Aciertos: 0.73
# Epoch: 419/5000: Pérdida: [0.5764378] Aciertos: 0.73
# Epoch: 420/5000: Pérdida: [0.57641528] Aciertos: 0.73
# Epoch: 421/5000: Pérdida: [0.57639271] Aciertos: 0.73
# Epoch: 422/5000: Pérdida: [0.57637006] Aciertos: 0.73
# Epoch: 423/5000: Pérdida: [0.57634736] Aciertos: 0.73
# Epoch: 424/5000: Pérdida: [0.57632459] Aciertos: 0.73
# Epoch: 425/5000: Pérdida: [0.57630175] Aciertos: 0.73
# Epoch: 426/5000: Pérdida: [0.57627884] Aciertos: 0.73
# Epoch: 427/5000: Pérdida: [0.57625587] Aciertos: 0.73
# Epoch: 428/5000: Pérdida: [0.57623283] Aciertos: 0.73
# Epoch: 429/5000: Pérdida: [0.57620972] Aciertos: 0.73
# Epoch: 430/5000: Pérdida: [0.57618654] Aciertos: 0.73
# Epoch: 431/5000: Pérdida: [0.5761633] Aciertos: 0.73
# Epoch: 432/5000: Pérdida: [0.57613998] Aciertos: 0.73
# Epoch: 433/5000: Pérdida: [0.5761166] Aciertos: 0.73
# Epoch: 434/5000: Pérdida: [0.57609314] Aciertos: 0.73
# Epoch: 435/5000: Pérdida: [0.57606961] Aciertos: 0.73
# Epoch: 436/5000: Pérdida: [0.57604602] Aciertos: 0.73
# Epoch: 437/5000: Pérdida: [0.57602235] Aciertos: 0.73
# Epoch: 438/5000: Pérdida: [0.57599861] Aciertos: 0.73
# Epoch: 439/5000: Pérdida: [0.57597479] Aciertos: 0.73
# Epoch: 440/5000: Pérdida: [0.5759509] Aciertos: 0.73
# Epoch: 441/5000: Pérdida: [0.57592694] Aciertos: 0.73
# Epoch: 442/5000: Pérdida: [0.57590291] Aciertos: 0.73
# Epoch: 443/5000: Pérdida: [0.5758788] Aciertos: 0.73
# Epoch: 444/5000: Pérdida: [0.57585462] Aciertos: 0.73
# Epoch: 445/5000: Pérdida: [0.57583036] Aciertos: 0.73
# Epoch: 446/5000: Pérdida: [0.57580603] Aciertos: 0.73
# Epoch: 447/5000: Pérdida: [0.57578162] Aciertos: 0.73
# Epoch: 448/5000: Pérdida: [0.57575713] Aciertos: 0.73
# Epoch: 449/5000: Pérdida: [0.57573257] Aciertos: 0.73
# Epoch: 450/5000: Pérdida: [0.57570793] Aciertos: 0.73
# Epoch: 451/5000: Pérdida: [0.57568321] Aciertos: 0.73
# Epoch: 452/5000: Pérdida: [0.57565842] Aciertos: 0.73
# Epoch: 453/5000: Pérdida: [0.57563354] Aciertos: 0.73
# Epoch: 454/5000: Pérdida: [0.57560859] Aciertos: 0.73
# Epoch: 455/5000: Pérdida: [0.57558356] Aciertos: 0.73
# Epoch: 456/5000: Pérdida: [0.57555845] Aciertos: 0.73
# Epoch: 457/5000: Pérdida: [0.57553326] Aciertos: 0.73
# Epoch: 458/5000: Pérdida: [0.57550799] Aciertos: 0.73
# Epoch: 459/5000: Pérdida: [0.57548264] Aciertos: 0.73
# Epoch: 460/5000: Pérdida: [0.57545721] Aciertos: 0.73
# Epoch: 461/5000: Pérdida: [0.5754317] Aciertos: 0.73
# Epoch: 462/5000: Pérdida: [0.57540611] Aciertos: 0.73
# Epoch: 463/5000: Pérdida: [0.57538043] Aciertos: 0.73
# Epoch: 464/5000: Pérdida: [0.57535467] Aciertos: 0.73
# Epoch: 465/5000: Pérdida: [0.57532883] Aciertos: 0.73
# Epoch: 466/5000: Pérdida: [0.5753029] Aciertos: 0.73
# Epoch: 467/5000: Pérdida: [0.57527689] Aciertos: 0.73
# Epoch: 468/5000: Pérdida: [0.5752508] Aciertos: 0.73
# Epoch: 469/5000: Pérdida: [0.57522462] Aciertos: 0.73
# Epoch: 470/5000: Pérdida: [0.57519836] Aciertos: 0.73
# Epoch: 471/5000: Pérdida: [0.57517201] Aciertos: 0.73
# Epoch: 472/5000: Pérdida: [0.57514558] Aciertos: 0.73
# Epoch: 473/5000: Pérdida: [0.57511906] Aciertos: 0.73
# Epoch: 474/5000: Pérdida: [0.57509245] Aciertos: 0.73
# Epoch: 475/5000: Pérdida: [0.57506576] Aciertos: 0.73
# Epoch: 476/5000: Pérdida: [0.57503898] Aciertos: 0.73
# Epoch: 477/5000: Pérdida: [0.57501211] Aciertos: 0.73
# Epoch: 478/5000: Pérdida: [0.57498515] Aciertos: 0.73
# Epoch: 479/5000: Pérdida: [0.57495811] Aciertos: 0.73
# Epoch: 480/5000: Pérdida: [0.57493097] Aciertos: 0.73
# Epoch: 481/5000: Pérdida: [0.57490375] Aciertos: 0.73
# Epoch: 482/5000: Pérdida: [0.57487643] Aciertos: 0.73
# Epoch: 483/5000: Pérdida: [0.57484903] Aciertos: 0.73
# Epoch: 484/5000: Pérdida: [0.57482154] Aciertos: 0.73
# Epoch: 485/5000: Pérdida: [0.57479395] Aciertos: 0.73
# Epoch: 486/5000: Pérdida: [0.57476627] Aciertos: 0.73
# Epoch: 487/5000: Pérdida: [0.5747385] Aciertos: 0.73
# Epoch: 488/5000: Pérdida: [0.57471064] Aciertos: 0.73
# Epoch: 489/5000: Pérdida: [0.57468269] Aciertos: 0.73
# Epoch: 490/5000: Pérdida: [0.57465464] Aciertos: 0.73
# Epoch: 491/5000: Pérdida: [0.5746265] Aciertos: 0.73
# Epoch: 492/5000: Pérdida: [0.57459826] Aciertos: 0.73
# Epoch: 493/5000: Pérdida: [0.57456993] Aciertos: 0.73
# Epoch: 494/5000: Pérdida: [0.5745415] Aciertos: 0.73
# Epoch: 495/5000: Pérdida: [0.57451298] Aciertos: 0.73
# Epoch: 496/5000: Pérdida: [0.57448436] Aciertos: 0.73
# Epoch: 497/5000: Pérdida: [0.57445565] Aciertos: 0.73
# Epoch: 498/5000: Pérdida: [0.57442684] Aciertos: 0.73
# Epoch: 499/5000: Pérdida: [0.57439793] Aciertos: 0.73
# Epoch: 500/5000: Pérdida: [0.57436893] Aciertos: 0.73
# Epoch: 501/5000: Pérdida: [0.57433982] Aciertos: 0.73
# Epoch: 502/5000: Pérdida: [0.57431062] Aciertos: 0.73
# Epoch: 503/5000: Pérdida: [0.57428132] Aciertos: 0.73
# Epoch: 504/5000: Pérdida: [0.57425192] Aciertos: 0.73
# Epoch: 505/5000: Pérdida: [0.57422242] Aciertos: 0.73
# Epoch: 506/5000: Pérdida: [0.57419282] Aciertos: 0.73
# Epoch: 507/5000: Pérdida: [0.57416311] Aciertos: 0.73
# Epoch: 508/5000: Pérdida: [0.57413331] Aciertos: 0.73
# Epoch: 509/5000: Pérdida: [0.57410341] Aciertos: 0.73
# Epoch: 510/5000: Pérdida: [0.5740734] Aciertos: 0.73
# Epoch: 511/5000: Pérdida: [0.57404329] Aciertos: 0.73
# Epoch: 512/5000: Pérdida: [0.57401307] Aciertos: 0.73
# Epoch: 513/5000: Pérdida: [0.57398276] Aciertos: 0.73
# Epoch: 514/5000: Pérdida: [0.57395233] Aciertos: 0.73
# Epoch: 515/5000: Pérdida: [0.57392181] Aciertos: 0.73
# Epoch: 516/5000: Pérdida: [0.57389118] Aciertos: 0.73
# Epoch: 517/5000: Pérdida: [0.57386044] Aciertos: 0.73
# Epoch: 518/5000: Pérdida: [0.57382959] Aciertos: 0.73
# Epoch: 519/5000: Pérdida: [0.57379864] Aciertos: 0.73
# Epoch: 520/5000: Pérdida: [0.57376759] Aciertos: 0.73
# Epoch: 521/5000: Pérdida: [0.57373642] Aciertos: 0.73
# Epoch: 522/5000: Pérdida: [0.57370515] Aciertos: 0.73
# Epoch: 523/5000: Pérdida: [0.57367377] Aciertos: 0.73
# Epoch: 524/5000: Pérdida: [0.57364228] Aciertos: 0.73
# Epoch: 525/5000: Pérdida: [0.57361068] Aciertos: 0.73
# Epoch: 526/5000: Pérdida: [0.57357897] Aciertos: 0.73
# Epoch: 527/5000: Pérdida: [0.57354715] Aciertos: 0.73
# Epoch: 528/5000: Pérdida: [0.57351522] Aciertos: 0.73
# Epoch: 529/5000: Pérdida: [0.57348318] Aciertos: 0.73
# Epoch: 530/5000: Pérdida: [0.57345103] Aciertos: 0.73
# Epoch: 531/5000: Pérdida: [0.57341876] Aciertos: 0.73
# Epoch: 532/5000: Pérdida: [0.57338639] Aciertos: 0.73
# Epoch: 533/5000: Pérdida: [0.57335389] Aciertos: 0.73
# Epoch: 534/5000: Pérdida: [0.57332129] Aciertos: 0.73
# Epoch: 535/5000: Pérdida: [0.57328857] Aciertos: 0.73
# Epoch: 536/5000: Pérdida: [0.57325574] Aciertos: 0.73
# Epoch: 537/5000: Pérdida: [0.57322279] Aciertos: 0.73
# Epoch: 538/5000: Pérdida: [0.57318973] Aciertos: 0.73
# Epoch: 539/5000: Pérdida: [0.57315655] Aciertos: 0.73
# Epoch: 540/5000: Pérdida: [0.57312325] Aciertos: 0.73
# Epoch: 541/5000: Pérdida: [0.57308984] Aciertos: 0.73
# Epoch: 542/5000: Pérdida: [0.57305631] Aciertos: 0.73
# Epoch: 543/5000: Pérdida: [0.57302266] Aciertos: 0.73
# Epoch: 544/5000: Pérdida: [0.57298889] Aciertos: 0.73
# Epoch: 545/5000: Pérdida: [0.57295501] Aciertos: 0.73
# Epoch: 546/5000: Pérdida: [0.57292101] Aciertos: 0.73
# Epoch: 547/5000: Pérdida: [0.57288688] Aciertos: 0.73
# Epoch: 548/5000: Pérdida: [0.57285264] Aciertos: 0.73
# Epoch: 549/5000: Pérdida: [0.57281828] Aciertos: 0.73
# Epoch: 550/5000: Pérdida: [0.57278379] Aciertos: 0.73
# Epoch: 551/5000: Pérdida: [0.57274919] Aciertos: 0.73
# Epoch: 552/5000: Pérdida: [0.57271446] Aciertos: 0.73
# Epoch: 553/5000: Pérdida: [0.57267961] Aciertos: 0.73
# Epoch: 554/5000: Pérdida: [0.57264464] Aciertos: 0.73
# Epoch: 555/5000: Pérdida: [0.57260954] Aciertos: 0.73
# Epoch: 556/5000: Pérdida: [0.57257433] Aciertos: 0.73
# Epoch: 557/5000: Pérdida: [0.57253898] Aciertos: 0.73
# Epoch: 558/5000: Pérdida: [0.57250352] Aciertos: 0.73
# Epoch: 559/5000: Pérdida: [0.57246793] Aciertos: 0.73
# Epoch: 560/5000: Pérdida: [0.57243221] Aciertos: 0.73
# Epoch: 561/5000: Pérdida: [0.57239637] Aciertos: 0.73
# Epoch: 562/5000: Pérdida: [0.5723604] Aciertos: 0.73
# Epoch: 563/5000: Pérdida: [0.57232431] Aciertos: 0.73
# Epoch: 564/5000: Pérdida: [0.57228809] Aciertos: 0.73
# Epoch: 565/5000: Pérdida: [0.57225174] Aciertos: 0.73
# Epoch: 566/5000: Pérdida: [0.57221527] Aciertos: 0.73
# Epoch: 567/5000: Pérdida: [0.57217866] Aciertos: 0.73
# Epoch: 568/5000: Pérdida: [0.57214193] Aciertos: 0.73
# Epoch: 569/5000: Pérdida: [0.57210507] Aciertos: 0.73
# Epoch: 570/5000: Pérdida: [0.57206809] Aciertos: 0.73
# Epoch: 571/5000: Pérdida: [0.57203097] Aciertos: 0.73
# Epoch: 572/5000: Pérdida: [0.57199372] Aciertos: 0.73
# Epoch: 573/5000: Pérdida: [0.57195634] Aciertos: 0.73
# Epoch: 574/5000: Pérdida: [0.57191884] Aciertos: 0.73
# Epoch: 575/5000: Pérdida: [0.5718812] Aciertos: 0.73
# Epoch: 576/5000: Pérdida: [0.57184343] Aciertos: 0.73
# Epoch: 577/5000: Pérdida: [0.57180553] Aciertos: 0.73
# Epoch: 578/5000: Pérdida: [0.57176749] Aciertos: 0.73
# Epoch: 579/5000: Pérdida: [0.57172933] Aciertos: 0.73
# Epoch: 580/5000: Pérdida: [0.57169103] Aciertos: 0.73
# Epoch: 581/5000: Pérdida: [0.5716526] Aciertos: 0.73
# Epoch: 582/5000: Pérdida: [0.57161403] Aciertos: 0.73
# Epoch: 583/5000: Pérdida: [0.57157533] Aciertos: 0.73
# Epoch: 584/5000: Pérdida: [0.5715365] Aciertos: 0.73
# Epoch: 585/5000: Pérdida: [0.57149753] Aciertos: 0.73
# Epoch: 586/5000: Pérdida: [0.57145843] Aciertos: 0.73
# Epoch: 587/5000: Pérdida: [0.57141919] Aciertos: 0.73
# Epoch: 588/5000: Pérdida: [0.57137982] Aciertos: 0.73
# Epoch: 589/5000: Pérdida: [0.57134031] Aciertos: 0.73
# Epoch: 590/5000: Pérdida: [0.57130067] Aciertos: 0.73
# Epoch: 591/5000: Pérdida: [0.57126089] Aciertos: 0.73
# Epoch: 592/5000: Pérdida: [0.57122097] Aciertos: 0.73
# Epoch: 593/5000: Pérdida: [0.57118091] Aciertos: 0.73
# Epoch: 594/5000: Pérdida: [0.57114072] Aciertos: 0.73
# Epoch: 595/5000: Pérdida: [0.57110039] Aciertos: 0.73
# Epoch: 596/5000: Pérdida: [0.57105992] Aciertos: 0.73
# Epoch: 597/5000: Pérdida: [0.57101931] Aciertos: 0.73
# Epoch: 598/5000: Pérdida: [0.57097856] Aciertos: 0.73
# Epoch: 599/5000: Pérdida: [0.57093767] Aciertos: 0.73
# Epoch: 600/5000: Pérdida: [0.57089665] Aciertos: 0.73
# Epoch: 601/5000: Pérdida: [0.57085548] Aciertos: 0.73
# Epoch: 602/5000: Pérdida: [0.57081417] Aciertos: 0.73
# Epoch: 603/5000: Pérdida: [0.57077272] Aciertos: 0.73
# Epoch: 604/5000: Pérdida: [0.57073113] Aciertos: 0.73
# Epoch: 605/5000: Pérdida: [0.5706894] Aciertos: 0.73
# Epoch: 606/5000: Pérdida: [0.57064753] Aciertos: 0.73
# Epoch: 607/5000: Pérdida: [0.57060551] Aciertos: 0.73
# Epoch: 608/5000: Pérdida: [0.57056335] Aciertos: 0.73
# Epoch: 609/5000: Pérdida: [0.57052105] Aciertos: 0.73
# Epoch: 610/5000: Pérdida: [0.57047861] Aciertos: 0.73
# Epoch: 611/5000: Pérdida: [0.57043602] Aciertos: 0.73
# Epoch: 612/5000: Pérdida: [0.57039329] Aciertos: 0.73
# Epoch: 613/5000: Pérdida: [0.57035041] Aciertos: 0.73
# Epoch: 614/5000: Pérdida: [0.57030739] Aciertos: 0.73
# Epoch: 615/5000: Pérdida: [0.57026422] Aciertos: 0.73
# Epoch: 616/5000: Pérdida: [0.57022091] Aciertos: 0.73
# Epoch: 617/5000: Pérdida: [0.57017745] Aciertos: 0.73
# Epoch: 618/5000: Pérdida: [0.57013385] Aciertos: 0.73
# Epoch: 619/5000: Pérdida: [0.57009009] Aciertos: 0.73
# Epoch: 620/5000: Pérdida: [0.57004619] Aciertos: 0.73
# Epoch: 621/5000: Pérdida: [0.57000215] Aciertos: 0.73
# Epoch: 622/5000: Pérdida: [0.56995795] Aciertos: 0.73
# Epoch: 623/5000: Pérdida: [0.56991361] Aciertos: 0.73
# Epoch: 624/5000: Pérdida: [0.56986912] Aciertos: 0.73
# Epoch: 625/5000: Pérdida: [0.56982448] Aciertos: 0.73
# Epoch: 626/5000: Pérdida: [0.56977969] Aciertos: 0.73
# Epoch: 627/5000: Pérdida: [0.56973475] Aciertos: 0.73
# Epoch: 628/5000: Pérdida: [0.56968966] Aciertos: 0.73
# Epoch: 629/5000: Pérdida: [0.56964442] Aciertos: 0.73
# Epoch: 630/5000: Pérdida: [0.56959903] Aciertos: 0.73
# Epoch: 631/5000: Pérdida: [0.56955348] Aciertos: 0.73
# Epoch: 632/5000: Pérdida: [0.56950779] Aciertos: 0.73
# Epoch: 633/5000: Pérdida: [0.56946194] Aciertos: 0.73
# Epoch: 634/5000: Pérdida: [0.56941594] Aciertos: 0.73
# Epoch: 635/5000: Pérdida: [0.56936979] Aciertos: 0.73
# Epoch: 636/5000: Pérdida: [0.56932348] Aciertos: 0.73
# Epoch: 637/5000: Pérdida: [0.56927702] Aciertos: 0.73
# Epoch: 638/5000: Pérdida: [0.56923041] Aciertos: 0.73
# Epoch: 639/5000: Pérdida: [0.56918364] Aciertos: 0.73
# Epoch: 640/5000: Pérdida: [0.56913671] Aciertos: 0.73
# Epoch: 641/5000: Pérdida: [0.56908963] Aciertos: 0.73
# Epoch: 642/5000: Pérdida: [0.56904239] Aciertos: 0.73
# Epoch: 643/5000: Pérdida: [0.568995] Aciertos: 0.73
# Epoch: 644/5000: Pérdida: [0.56894745] Aciertos: 0.73
# Epoch: 645/5000: Pérdida: [0.56889975] Aciertos: 0.73
# Epoch: 646/5000: Pérdida: [0.56885188] Aciertos: 0.73
# Epoch: 647/5000: Pérdida: [0.56880386] Aciertos: 0.73
# Epoch: 648/5000: Pérdida: [0.56875568] Aciertos: 0.73
# Epoch: 649/5000: Pérdida: [0.56870734] Aciertos: 0.73
# Epoch: 650/5000: Pérdida: [0.56865884] Aciertos: 0.73
# Epoch: 651/5000: Pérdida: [0.56861018] Aciertos: 0.73
# Epoch: 652/5000: Pérdida: [0.56856136] Aciertos: 0.73
# Epoch: 653/5000: Pérdida: [0.56851238] Aciertos: 0.73
# Epoch: 654/5000: Pérdida: [0.56846323] Aciertos: 0.73
# Epoch: 655/5000: Pérdida: [0.56841393] Aciertos: 0.73
# Epoch: 656/5000: Pérdida: [0.56836447] Aciertos: 0.73
# Epoch: 657/5000: Pérdida: [0.56831484] Aciertos: 0.73
# Epoch: 658/5000: Pérdida: [0.56826505] Aciertos: 0.73
# Epoch: 659/5000: Pérdida: [0.56821509] Aciertos: 0.73
# Epoch: 660/5000: Pérdida: [0.56816497] Aciertos: 0.73
# Epoch: 661/5000: Pérdida: [0.56811469] Aciertos: 0.73
# Epoch: 662/5000: Pérdida: [0.56806424] Aciertos: 0.73
# Epoch: 663/5000: Pérdida: [0.56801363] Aciertos: 0.73
# Epoch: 664/5000: Pérdida: [0.56796285] Aciertos: 0.73
# Epoch: 665/5000: Pérdida: [0.56791191] Aciertos: 0.73
# Epoch: 666/5000: Pérdida: [0.5678608] Aciertos: 0.73
# Epoch: 667/5000: Pérdida: [0.56780952] Aciertos: 0.73
# Epoch: 668/5000: Pérdida: [0.56775807] Aciertos: 0.73
# Epoch: 669/5000: Pérdida: [0.56770646] Aciertos: 0.73
# Epoch: 670/5000: Pérdida: [0.56765468] Aciertos: 0.73
# Epoch: 671/5000: Pérdida: [0.56760272] Aciertos: 0.73
# Epoch: 672/5000: Pérdida: [0.5675506] Aciertos: 0.73
# Epoch: 673/5000: Pérdida: [0.56749831] Aciertos: 0.73
# Epoch: 674/5000: Pérdida: [0.56744585] Aciertos: 0.73
# Epoch: 675/5000: Pérdida: [0.56739322] Aciertos: 0.73
# Epoch: 676/5000: Pérdida: [0.56734042] Aciertos: 0.73
# Epoch: 677/5000: Pérdida: [0.56728744] Aciertos: 0.73
# Epoch: 678/5000: Pérdida: [0.56723429] Aciertos: 0.73
# Epoch: 679/5000: Pérdida: [0.56718097] Aciertos: 0.73
# Epoch: 680/5000: Pérdida: [0.56712748] Aciertos: 0.73
# Epoch: 681/5000: Pérdida: [0.56707381] Aciertos: 0.73
# Epoch: 682/5000: Pérdida: [0.56701997] Aciertos: 0.73
# Epoch: 683/5000: Pérdida: [0.56696596] Aciertos: 0.73
# Epoch: 684/5000: Pérdida: [0.56691177] Aciertos: 0.73
# Epoch: 685/5000: Pérdida: [0.5668574] Aciertos: 0.73
# Epoch: 686/5000: Pérdida: [0.56680286] Aciertos: 0.73
# Epoch: 687/5000: Pérdida: [0.56674814] Aciertos: 0.73
# Epoch: 688/5000: Pérdida: [0.56669324] Aciertos: 0.73
# Epoch: 689/5000: Pérdida: [0.56663816] Aciertos: 0.73
# Epoch: 690/5000: Pérdida: [0.56658291] Aciertos: 0.73
# Epoch: 691/5000: Pérdida: [0.56652748] Aciertos: 0.73
# Epoch: 692/5000: Pérdida: [0.56647187] Aciertos: 0.73
# Epoch: 693/5000: Pérdida: [0.56641608] Aciertos: 0.73
# Epoch: 694/5000: Pérdida: [0.5663601] Aciertos: 0.73
# Epoch: 695/5000: Pérdida: [0.56630395] Aciertos: 0.73
# Epoch: 696/5000: Pérdida: [0.56624762] Aciertos: 0.73
# Epoch: 697/5000: Pérdida: [0.5661911] Aciertos: 0.73
# Epoch: 698/5000: Pérdida: [0.56613441] Aciertos: 0.73
# Epoch: 699/5000: Pérdida: [0.56607753] Aciertos: 0.73
# Epoch: 700/5000: Pérdida: [0.56602046] Aciertos: 0.73
# Epoch: 701/5000: Pérdida: [0.56596322] Aciertos: 0.73
# Epoch: 702/5000: Pérdida: [0.56590578] Aciertos: 0.73
# Epoch: 703/5000: Pérdida: [0.56584817] Aciertos: 0.73
# Epoch: 704/5000: Pérdida: [0.56579036] Aciertos: 0.73
# Epoch: 705/5000: Pérdida: [0.56573238] Aciertos: 0.73
# Epoch: 706/5000: Pérdida: [0.5656742] Aciertos: 0.73
# Epoch: 707/5000: Pérdida: [0.56561584] Aciertos: 0.73
# Epoch: 708/5000: Pérdida: [0.56555729] Aciertos: 0.73
# Epoch: 709/5000: Pérdida: [0.56549855] Aciertos: 0.73
# Epoch: 710/5000: Pérdida: [0.56543962] Aciertos: 0.73
# Epoch: 711/5000: Pérdida: [0.56538051] Aciertos: 0.73
# Epoch: 712/5000: Pérdida: [0.5653212] Aciertos: 0.73
# Epoch: 713/5000: Pérdida: [0.56526171] Aciertos: 0.73
# Epoch: 714/5000: Pérdida: [0.56520202] Aciertos: 0.73
# Epoch: 715/5000: Pérdida: [0.56514214] Aciertos: 0.73
# Epoch: 716/5000: Pérdida: [0.56508207] Aciertos: 0.73
# Epoch: 717/5000: Pérdida: [0.5650218] Aciertos: 0.73
# Epoch: 718/5000: Pérdida: [0.56496135] Aciertos: 0.73
# Epoch: 719/5000: Pérdida: [0.5649007] Aciertos: 0.73
# Epoch: 720/5000: Pérdida: [0.56483985] Aciertos: 0.73
# Epoch: 721/5000: Pérdida: [0.56477881] Aciertos: 0.73
# Epoch: 722/5000: Pérdida: [0.56471757] Aciertos: 0.73
# Epoch: 723/5000: Pérdida: [0.56465614] Aciertos: 0.73
# Epoch: 724/5000: Pérdida: [0.56459451] Aciertos: 0.73
# Epoch: 725/5000: Pérdida: [0.56453269] Aciertos: 0.73
# Epoch: 726/5000: Pérdida: [0.56447066] Aciertos: 0.73
# Epoch: 727/5000: Pérdida: [0.56440844] Aciertos: 0.73
# Epoch: 728/5000: Pérdida: [0.56434602] Aciertos: 0.73
# Epoch: 729/5000: Pérdida: [0.5642834] Aciertos: 0.73
# Epoch: 730/5000: Pérdida: [0.56422058] Aciertos: 0.73
# Epoch: 731/5000: Pérdida: [0.56415756] Aciertos: 0.73
# Epoch: 732/5000: Pérdida: [0.56409433] Aciertos: 0.73
# Epoch: 733/5000: Pérdida: [0.56403091] Aciertos: 0.73
# Epoch: 734/5000: Pérdida: [0.56396728] Aciertos: 0.73
# Epoch: 735/5000: Pérdida: [0.56390344] Aciertos: 0.73
# Epoch: 736/5000: Pérdida: [0.56383941] Aciertos: 0.73
# Epoch: 737/5000: Pérdida: [0.56377517] Aciertos: 0.73
# Epoch: 738/5000: Pérdida: [0.56371072] Aciertos: 0.73
# Epoch: 739/5000: Pérdida: [0.56364607] Aciertos: 0.73
# Epoch: 740/5000: Pérdida: [0.56358121] Aciertos: 0.73
# Epoch: 741/5000: Pérdida: [0.56351615] Aciertos: 0.73
# Epoch: 742/5000: Pérdida: [0.56345087] Aciertos: 0.73
# Epoch: 743/5000: Pérdida: [0.56338539] Aciertos: 0.73
# Epoch: 744/5000: Pérdida: [0.5633197] Aciertos: 0.73
# Epoch: 745/5000: Pérdida: [0.5632538] Aciertos: 0.73
# Epoch: 746/5000: Pérdida: [0.56318769] Aciertos: 0.73
# Epoch: 747/5000: Pérdida: [0.56312137] Aciertos: 0.73
# Epoch: 748/5000: Pérdida: [0.56305484] Aciertos: 0.73
# Epoch: 749/5000: Pérdida: [0.56298809] Aciertos: 0.73
# Epoch: 750/5000: Pérdida: [0.56292113] Aciertos: 0.73
# Epoch: 751/5000: Pérdida: [0.56285396] Aciertos: 0.73
# Epoch: 752/5000: Pérdida: [0.56278657] Aciertos: 0.73
# Epoch: 753/5000: Pérdida: [0.56271897] Aciertos: 0.73
# Epoch: 754/5000: Pérdida: [0.56265115] Aciertos: 0.73
# Epoch: 755/5000: Pérdida: [0.56258312] Aciertos: 0.73
# Epoch: 756/5000: Pérdida: [0.56251487] Aciertos: 0.73
# Epoch: 757/5000: Pérdida: [0.5624464] Aciertos: 0.73
# Epoch: 758/5000: Pérdida: [0.56237771] Aciertos: 0.73
# Epoch: 759/5000: Pérdida: [0.5623088] Aciertos: 0.73
# Epoch: 760/5000: Pérdida: [0.56223968] Aciertos: 0.73
# Epoch: 761/5000: Pérdida: [0.56217033] Aciertos: 0.73
# Epoch: 762/5000: Pérdida: [0.56210076] Aciertos: 0.73
# Epoch: 763/5000: Pérdida: [0.56203097] Aciertos: 0.73
# Epoch: 764/5000: Pérdida: [0.56196096] Aciertos: 0.73
# Epoch: 765/5000: Pérdida: [0.56189072] Aciertos: 0.73
# Epoch: 766/5000: Pérdida: [0.56182026] Aciertos: 0.73
# Epoch: 767/5000: Pérdida: [0.56174957] Aciertos: 0.73
# Epoch: 768/5000: Pérdida: [0.56167866] Aciertos: 0.73
# Epoch: 769/5000: Pérdida: [0.56160752] Aciertos: 0.73
# Epoch: 770/5000: Pérdida: [0.56153615] Aciertos: 0.73
# Epoch: 771/5000: Pérdida: [0.56146456] Aciertos: 0.73
# Epoch: 772/5000: Pérdida: [0.56139273] Aciertos: 0.73
# Epoch: 773/5000: Pérdida: [0.56132068] Aciertos: 0.73
# Epoch: 774/5000: Pérdida: [0.5612484] Aciertos: 0.73
# Epoch: 775/5000: Pérdida: [0.56117588] Aciertos: 0.73
# Epoch: 776/5000: Pérdida: [0.56110314] Aciertos: 0.73
# Epoch: 777/5000: Pérdida: [0.56103016] Aciertos: 0.73
# Epoch: 778/5000: Pérdida: [0.56095695] Aciertos: 0.73
# Epoch: 779/5000: Pérdida: [0.5608835] Aciertos: 0.73
# Epoch: 780/5000: Pérdida: [0.56080982] Aciertos: 0.73
# Epoch: 781/5000: Pérdida: [0.5607359] Aciertos: 0.73
# Epoch: 782/5000: Pérdida: [0.56066175] Aciertos: 0.73
# Epoch: 783/5000: Pérdida: [0.56058736] Aciertos: 0.73
# Epoch: 784/5000: Pérdida: [0.56051273] Aciertos: 0.73
# Epoch: 785/5000: Pérdida: [0.56043786] Aciertos: 0.73
# Epoch: 786/5000: Pérdida: [0.56036275] Aciertos: 0.73
# Epoch: 787/5000: Pérdida: [0.5602874] Aciertos: 0.73
# Epoch: 788/5000: Pérdida: [0.56021181] Aciertos: 0.73
# Epoch: 789/5000: Pérdida: [0.56013597] Aciertos: 0.73
# Epoch: 790/5000: Pérdida: [0.56005989] Aciertos: 0.73
# Epoch: 791/5000: Pérdida: [0.55998357] Aciertos: 0.73
# Epoch: 792/5000: Pérdida: [0.55990701] Aciertos: 0.73
# Epoch: 793/5000: Pérdida: [0.55983019] Aciertos: 0.73
# Epoch: 794/5000: Pérdida: [0.55975313] Aciertos: 0.73
# Epoch: 795/5000: Pérdida: [0.55967583] Aciertos: 0.73
# Epoch: 796/5000: Pérdida: [0.55959827] Aciertos: 0.73
# Epoch: 797/5000: Pérdida: [0.55952046] Aciertos: 0.73
# Epoch: 798/5000: Pérdida: [0.55944241] Aciertos: 0.73
# Epoch: 799/5000: Pérdida: [0.5593641] Aciertos: 0.73
# Epoch: 800/5000: Pérdida: [0.55928554] Aciertos: 0.73
# Epoch: 801/5000: Pérdida: [0.55920673] Aciertos: 0.73
# Epoch: 802/5000: Pérdida: [0.55912766] Aciertos: 0.73
# Epoch: 803/5000: Pérdida: [0.55904834] Aciertos: 0.73
# Epoch: 804/5000: Pérdida: [0.55896876] Aciertos: 0.73
# Epoch: 805/5000: Pérdida: [0.55888893] Aciertos: 0.73
# Epoch: 806/5000: Pérdida: [0.55880884] Aciertos: 0.73
# Epoch: 807/5000: Pérdida: [0.55872848] Aciertos: 0.73
# Epoch: 808/5000: Pérdida: [0.55864787] Aciertos: 0.73
# Epoch: 809/5000: Pérdida: [0.558567] Aciertos: 0.73
# Epoch: 810/5000: Pérdida: [0.55848587] Aciertos: 0.73
# Epoch: 811/5000: Pérdida: [0.55840447] Aciertos: 0.73
# Epoch: 812/5000: Pérdida: [0.55832281] Aciertos: 0.73
# Epoch: 813/5000: Pérdida: [0.55824089] Aciertos: 0.73
# Epoch: 814/5000: Pérdida: [0.5581587] Aciertos: 0.73
# Epoch: 815/5000: Pérdida: [0.55807624] Aciertos: 0.73
# Epoch: 816/5000: Pérdida: [0.55799352] Aciertos: 0.73
# Epoch: 817/5000: Pérdida: [0.55791052] Aciertos: 0.73
# Epoch: 818/5000: Pérdida: [0.55782726] Aciertos: 0.73
# Epoch: 819/5000: Pérdida: [0.55774373] Aciertos: 0.73
# Epoch: 820/5000: Pérdida: [0.55765992] Aciertos: 0.73
# Epoch: 821/5000: Pérdida: [0.55757584] Aciertos: 0.73
# Epoch: 822/5000: Pérdida: [0.55749149] Aciertos: 0.73
# Epoch: 823/5000: Pérdida: [0.55740686] Aciertos: 0.73
# Epoch: 824/5000: Pérdida: [0.55732196] Aciertos: 0.73
# Epoch: 825/5000: Pérdida: [0.55723678] Aciertos: 0.73
# Epoch: 826/5000: Pérdida: [0.55715132] Aciertos: 0.73
# Epoch: 827/5000: Pérdida: [0.55706558] Aciertos: 0.73
# Epoch: 828/5000: Pérdida: [0.55697956] Aciertos: 0.73
# Epoch: 829/5000: Pérdida: [0.55689326] Aciertos: 0.73
# Epoch: 830/5000: Pérdida: [0.55680668] Aciertos: 0.73
# Epoch: 831/5000: Pérdida: [0.55671981] Aciertos: 0.73
# Epoch: 832/5000: Pérdida: [0.55663266] Aciertos: 0.73
# Epoch: 833/5000: Pérdida: [0.55654522] Aciertos: 0.73
# Epoch: 834/5000: Pérdida: [0.5564575] Aciertos: 0.73
# Epoch: 835/5000: Pérdida: [0.55636949] Aciertos: 0.73
# Epoch: 836/5000: Pérdida: [0.55628118] Aciertos: 0.73
# Epoch: 837/5000: Pérdida: [0.55619259] Aciertos: 0.73
# Epoch: 838/5000: Pérdida: [0.55610371] Aciertos: 0.73
# Epoch: 839/5000: Pérdida: [0.55601453] Aciertos: 0.73
# Epoch: 840/5000: Pérdida: [0.55592505] Aciertos: 0.73
# Epoch: 841/5000: Pérdida: [0.55583529] Aciertos: 0.73
# Epoch: 842/5000: Pérdida: [0.55574522] Aciertos: 0.73
# Epoch: 843/5000: Pérdida: [0.55565486] Aciertos: 0.73
# Epoch: 844/5000: Pérdida: [0.5555642] Aciertos: 0.73
# Epoch: 845/5000: Pérdida: [0.55547324] Aciertos: 0.73
# Epoch: 846/5000: Pérdida: [0.55538197] Aciertos: 0.73
# Epoch: 847/5000: Pérdida: [0.55529041] Aciertos: 0.73
# Epoch: 848/5000: Pérdida: [0.55519854] Aciertos: 0.73
# Epoch: 849/5000: Pérdida: [0.55510636] Aciertos: 0.73
# Epoch: 850/5000: Pérdida: [0.55501388] Aciertos: 0.73
# Epoch: 851/5000: Pérdida: [0.55492109] Aciertos: 0.73
# Epoch: 852/5000: Pérdida: [0.55482799] Aciertos: 0.73
# Epoch: 853/5000: Pérdida: [0.55473458] Aciertos: 0.73
# Epoch: 854/5000: Pérdida: [0.55464086] Aciertos: 0.73
# Epoch: 855/5000: Pérdida: [0.55454682] Aciertos: 0.73
# Epoch: 856/5000: Pérdida: [0.55445247] Aciertos: 0.73
# Epoch: 857/5000: Pérdida: [0.55435781] Aciertos: 0.73
# Epoch: 858/5000: Pérdida: [0.55426283] Aciertos: 0.73
# Epoch: 859/5000: Pérdida: [0.55416752] Aciertos: 0.73
# Epoch: 860/5000: Pérdida: [0.5540719] Aciertos: 0.73
# Epoch: 861/5000: Pérdida: [0.55397596] Aciertos: 0.73
# Epoch: 862/5000: Pérdida: [0.5538797] Aciertos: 0.73
# Epoch: 863/5000: Pérdida: [0.55378311] Aciertos: 0.73
# Epoch: 864/5000: Pérdida: [0.5536862] Aciertos: 0.73
# Epoch: 865/5000: Pérdida: [0.55358896] Aciertos: 0.73
# Epoch: 866/5000: Pérdida: [0.55349139] Aciertos: 0.73
# Epoch: 867/5000: Pérdida: [0.55339349] Aciertos: 0.73
# Epoch: 868/5000: Pérdida: [0.55329526] Aciertos: 0.73
# Epoch: 869/5000: Pérdida: [0.5531967] Aciertos: 0.73
# Epoch: 870/5000: Pérdida: [0.5530978] Aciertos: 0.73
# Epoch: 871/5000: Pérdida: [0.55299857] Aciertos: 0.73
# Epoch: 872/5000: Pérdida: [0.552899] Aciertos: 0.73
# Epoch: 873/5000: Pérdida: [0.5527991] Aciertos: 0.73
# Epoch: 874/5000: Pérdida: [0.55269885] Aciertos: 0.73
# Epoch: 875/5000: Pérdida: [0.55259826] Aciertos: 0.73
# Epoch: 876/5000: Pérdida: [0.55249733] Aciertos: 0.73
# Epoch: 877/5000: Pérdida: [0.55239606] Aciertos: 0.73
# Epoch: 878/5000: Pérdida: [0.55229444] Aciertos: 0.73
# Epoch: 879/5000: Pérdida: [0.55219247] Aciertos: 0.73
# Epoch: 880/5000: Pérdida: [0.55209016] Aciertos: 0.73
# Epoch: 881/5000: Pérdida: [0.55198749] Aciertos: 0.73
# Epoch: 882/5000: Pérdida: [0.55188447] Aciertos: 0.73
# Epoch: 883/5000: Pérdida: [0.5517811] Aciertos: 0.73
# Epoch: 884/5000: Pérdida: [0.55167737] Aciertos: 0.73
# Epoch: 885/5000: Pérdida: [0.55157329] Aciertos: 0.73
# Epoch: 886/5000: Pérdida: [0.55146885] Aciertos: 0.73
# Epoch: 887/5000: Pérdida: [0.55136405] Aciertos: 0.73
# Epoch: 888/5000: Pérdida: [0.55125888] Aciertos: 0.73
# Epoch: 889/5000: Pérdida: [0.55115336] Aciertos: 0.73
# Epoch: 890/5000: Pérdida: [0.55104747] Aciertos: 0.73
# Epoch: 891/5000: Pérdida: [0.55094121] Aciertos: 0.73
# ...
# Epoch: 4709/5000: Pérdida: [0.17309572] Aciertos: 0.96
# Epoch: 4710/5000: Pérdida: [0.17304273] Aciertos: 0.96
# Epoch: 4711/5000: Pérdida: [0.17298891] Aciertos: 0.96
# Epoch: 4712/5000: Pérdida: [0.17293424] Aciertos: 0.96
# Epoch: 4713/5000: Pérdida: [0.17287872] Aciertos: 0.96
# Epoch: 4714/5000: Pérdida: [0.17282235] Aciertos: 0.96
# Epoch: 4715/5000: Pérdida: [0.17276512] Aciertos: 0.96
# Epoch: 4716/5000: Pérdida: [0.17270703] Aciertos: 0.96
# Epoch: 4717/5000: Pérdida: [0.17264808] Aciertos: 0.96
# Epoch: 4718/5000: Pérdida: [0.17258827] Aciertos: 0.96
# Epoch: 4719/5000: Pérdida: [0.1725276] Aciertos: 0.96
# Epoch: 4720/5000: Pérdida: [0.17246608] Aciertos: 0.96
# Epoch: 4721/5000: Pérdida: [0.1724037] Aciertos: 0.96
# Epoch: 4722/5000: Pérdida: [0.17234047] Aciertos: 0.96
# Epoch: 4723/5000: Pérdida: [0.17227641] Aciertos: 0.96
# Epoch: 4724/5000: Pérdida: [0.1722115] Aciertos: 0.96
# Epoch: 4725/5000: Pérdida: [0.17214577] Aciertos: 0.96
# Epoch: 4726/5000: Pérdida: [0.17207922] Aciertos: 0.96
# Epoch: 4727/5000: Pérdida: [0.17201186] Aciertos: 0.96
# Epoch: 4728/5000: Pérdida: [0.17194371] Aciertos: 0.96
# Epoch: 4729/5000: Pérdida: [0.17187477] Aciertos: 0.96
# Epoch: 4730/5000: Pérdida: [0.17180506] Aciertos: 0.96
# Epoch: 4731/5000: Pérdida: [0.1717346] Aciertos: 0.96
# Epoch: 4732/5000: Pérdida: [0.17166339] Aciertos: 0.96
# Epoch: 4733/5000: Pérdida: [0.17159146] Aciertos: 0.96
# Epoch: 4734/5000: Pérdida: [0.17151883] Aciertos: 0.96
# Epoch: 4735/5000: Pérdida: [0.1714455] Aciertos: 0.96
# Epoch: 4736/5000: Pérdida: [0.1713715] Aciertos: 0.96
# Epoch: 4737/5000: Pérdida: [0.17129685] Aciertos: 0.96
# Epoch: 4738/5000: Pérdida: [0.17122157] Aciertos: 0.96
# Epoch: 4739/5000: Pérdida: [0.17114568] Aciertos: 0.96
# Epoch: 4740/5000: Pérdida: [0.1710692] Aciertos: 0.96
# Epoch: 4741/5000: Pérdida: [0.17099215] Aciertos: 0.96
# Epoch: 4742/5000: Pérdida: [0.17091456] Aciertos: 0.96
# Epoch: 4743/5000: Pérdida: [0.17083644] Aciertos: 0.96
# Epoch: 4744/5000: Pérdida: [0.17075782] Aciertos: 0.96
# Epoch: 4745/5000: Pérdida: [0.17067873] Aciertos: 0.96
# Epoch: 4746/5000: Pérdida: [0.17059917] Aciertos: 0.96
# Epoch: 4747/5000: Pérdida: [0.17051919] Aciertos: 0.96
# Epoch: 4748/5000: Pérdida: [0.1704388] Aciertos: 0.96
# Epoch: 4749/5000: Pérdida: [0.17035802] Aciertos: 0.96
# Epoch: 4750/5000: Pérdida: [0.17027688] Aciertos: 0.96
# Epoch: 4751/5000: Pérdida: [0.17019539] Aciertos: 0.96
# Epoch: 4752/5000: Pérdida: [0.17011359] Aciertos: 0.96
# Epoch: 4753/5000: Pérdida: [0.17003149] Aciertos: 0.96
# Epoch: 4754/5000: Pérdida: [0.16994911] Aciertos: 0.96
# Epoch: 4755/5000: Pérdida: [0.16986649] Aciertos: 0.96
# Epoch: 4756/5000: Pérdida: [0.16978363] Aciertos: 0.96
# Epoch: 4757/5000: Pérdida: [0.16970055] Aciertos: 0.96
# Epoch: 4758/5000: Pérdida: [0.16961728] Aciertos: 0.96
# Epoch: 4759/5000: Pérdida: [0.16953384] Aciertos: 0.96
# Epoch: 4760/5000: Pérdida: [0.16945025] Aciertos: 0.96
# Epoch: 4761/5000: Pérdida: [0.16936652] Aciertos: 0.96
# Epoch: 4762/5000: Pérdida: [0.16928267] Aciertos: 0.96
# Epoch: 4763/5000: Pérdida: [0.16919871] Aciertos: 0.96
# Epoch: 4764/5000: Pérdida: [0.16911467] Aciertos: 0.96
# Epoch: 4765/5000: Pérdida: [0.16903056] Aciertos: 0.96
# Epoch: 4766/5000: Pérdida: [0.1689464] Aciertos: 0.96
# Epoch: 4767/5000: Pérdida: [0.16886219] Aciertos: 0.96
# Epoch: 4768/5000: Pérdida: [0.16877795] Aciertos: 0.96
# Epoch: 4769/5000: Pérdida: [0.16869371] Aciertos: 0.96
# Epoch: 4770/5000: Pérdida: [0.16860946] Aciertos: 0.96
# Epoch: 4771/5000: Pérdida: [0.16852522] Aciertos: 0.96
# Epoch: 4772/5000: Pérdida: [0.168441] Aciertos: 0.96
# Epoch: 4773/5000: Pérdida: [0.16835682] Aciertos: 0.96
# Epoch: 4774/5000: Pérdida: [0.16827269] Aciertos: 0.96
# Epoch: 4775/5000: Pérdida: [0.16818861] Aciertos: 0.96
# Epoch: 4776/5000: Pérdida: [0.16810459] Aciertos: 0.96
# Epoch: 4777/5000: Pérdida: [0.16802065] Aciertos: 0.96
# Epoch: 4778/5000: Pérdida: [0.1679368] Aciertos: 0.96
# Epoch: 4779/5000: Pérdida: [0.16785304] Aciertos: 0.96
# Epoch: 4780/5000: Pérdida: [0.16776938] Aciertos: 0.96
# Epoch: 4781/5000: Pérdida: [0.16768583] Aciertos: 0.96
# Epoch: 4782/5000: Pérdida: [0.16760241] Aciertos: 0.97
# Epoch: 4783/5000: Pérdida: [0.16751911] Aciertos: 0.97
# Epoch: 4784/5000: Pérdida: [0.16743595] Aciertos: 0.97
# Epoch: 4785/5000: Pérdida: [0.16735295] Aciertos: 0.97
# Epoch: 4786/5000: Pérdida: [0.16727009] Aciertos: 0.97
# Epoch: 4787/5000: Pérdida: [0.16718741] Aciertos: 0.97
# Epoch: 4788/5000: Pérdida: [0.16710489] Aciertos: 0.97
# Epoch: 4789/5000: Pérdida: [0.16702257] Aciertos: 0.97
# Epoch: 4790/5000: Pérdida: [0.16694043] Aciertos: 0.97
# Epoch: 4791/5000: Pérdida: [0.1668585] Aciertos: 0.97
# Epoch: 4792/5000: Pérdida: [0.16677679] Aciertos: 0.97
# Epoch: 4793/5000: Pérdida: [0.16669529] Aciertos: 0.97
# Epoch: 4794/5000: Pérdida: [0.16661404] Aciertos: 0.97
# Epoch: 4795/5000: Pérdida: [0.16653304] Aciertos: 0.97
# Epoch: 4796/5000: Pérdida: [0.16645229] Aciertos: 0.97
# Epoch: 4797/5000: Pérdida: [0.16637182] Aciertos: 0.97
# Epoch: 4798/5000: Pérdida: [0.16629164] Aciertos: 0.97
# Epoch: 4799/5000: Pérdida: [0.16621175] Aciertos: 0.97
# Epoch: 4800/5000: Pérdida: [0.16613219] Aciertos: 0.97
# Epoch: 4801/5000: Pérdida: [0.16605296] Aciertos: 0.97
# Epoch: 4802/5000: Pérdida: [0.16597407] Aciertos: 0.97
# Epoch: 4803/5000: Pérdida: [0.16589556] Aciertos: 0.97
# Epoch: 4804/5000: Pérdida: [0.16581743] Aciertos: 0.97
# Epoch: 4805/5000: Pérdida: [0.16573971] Aciertos: 0.97
# Epoch: 4806/5000: Pérdida: [0.16566242] Aciertos: 0.97
# Epoch: 4807/5000: Pérdida: [0.16558558] Aciertos: 0.97
# Epoch: 4808/5000: Pérdida: [0.16550922] Aciertos: 0.97
# Epoch: 4809/5000: Pérdida: [0.16543335] Aciertos: 0.97
# Epoch: 4810/5000: Pérdida: [0.16535802] Aciertos: 0.97
# Epoch: 4811/5000: Pérdida: [0.16528324] Aciertos: 0.97
# Epoch: 4812/5000: Pérdida: [0.16520905] Aciertos: 0.97
# Epoch: 4813/5000: Pérdida: [0.16513548] Aciertos: 0.97
# Epoch: 4814/5000: Pérdida: [0.16506257] Aciertos: 0.97
# Epoch: 4815/5000: Pérdida: [0.16499035] Aciertos: 0.97
# Epoch: 4816/5000: Pérdida: [0.16491886] Aciertos: 0.97
# Epoch: 4817/5000: Pérdida: [0.16484815] Aciertos: 0.97
# Epoch: 4818/5000: Pérdida: [0.16477825] Aciertos: 0.97
# Epoch: 4819/5000: Pérdida: [0.16470922] Aciertos: 0.97
# Epoch: 4820/5000: Pérdida: [0.1646411] Aciertos: 0.97
# Epoch: 4821/5000: Pérdida: [0.16457395] Aciertos: 0.97
# Epoch: 4822/5000: Pérdida: [0.16450782] Aciertos: 0.97
# Epoch: 4823/5000: Pérdida: [0.16444278] Aciertos: 0.97
# Epoch: 4824/5000: Pérdida: [0.16437888] Aciertos: 0.97
# Epoch: 4825/5000: Pérdida: [0.16431618] Aciertos: 0.97
# Epoch: 4826/5000: Pérdida: [0.16425477] Aciertos: 0.97
# Epoch: 4827/5000: Pérdida: [0.16419471] Aciertos: 0.97
# Epoch: 4828/5000: Pérdida: [0.16413608] Aciertos: 0.97
# Epoch: 4829/5000: Pérdida: [0.16407895] Aciertos: 0.97
# Epoch: 4830/5000: Pérdida: [0.16402341] Aciertos: 0.97
# Epoch: 4831/5000: Pérdida: [0.16396955] Aciertos: 0.97
# Epoch: 4832/5000: Pérdida: [0.16391745] Aciertos: 0.97
# Epoch: 4833/5000: Pérdida: [0.16386721] Aciertos: 0.97
# Epoch: 4834/5000: Pérdida: [0.16381891] Aciertos: 0.97
# Epoch: 4835/5000: Pérdida: [0.16377266] Aciertos: 0.97
# Epoch: 4836/5000: Pérdida: [0.16372854] Aciertos: 0.97
# Epoch: 4837/5000: Pérdida: [0.16368667] Aciertos: 0.97
# Epoch: 4838/5000: Pérdida: [0.16364713] Aciertos: 0.97
# Epoch: 4839/5000: Pérdida: [0.16361002] Aciertos: 0.97
# Epoch: 4840/5000: Pérdida: [0.16357544] Aciertos: 0.97
# Epoch: 4841/5000: Pérdida: [0.16354347] Aciertos: 0.97
# Epoch: 4842/5000: Pérdida: [0.16351421] Aciertos: 0.97
# Epoch: 4843/5000: Pérdida: [0.16348774] Aciertos: 0.97
# Epoch: 4844/5000: Pérdida: [0.16346413] Aciertos: 0.97
# Epoch: 4845/5000: Pérdida: [0.16344345] Aciertos: 0.97
# Epoch: 4846/5000: Pérdida: [0.16342577] Aciertos: 0.97
# Epoch: 4847/5000: Pérdida: [0.16341114] Aciertos: 0.97
# Epoch: 4848/5000: Pérdida: [0.16339962] Aciertos: 0.97
# Epoch: 4849/5000: Pérdida: [0.16339125] Aciertos: 0.97
# Epoch: 4850/5000: Pérdida: [0.16338607] Aciertos: 0.97
# Epoch: 4851/5000: Pérdida: [0.1633841] Aciertos: 0.97
# Epoch: 4852/5000: Pérdida: [0.1633854] Aciertos: 0.97
# Epoch: 4853/5000: Pérdida: [0.16338999] Aciertos: 0.97
# Epoch: 4854/5000: Pérdida: [0.16339792] Aciertos: 0.97
# Epoch: 4855/5000: Pérdida: [0.16340923] Aciertos: 0.97
# Epoch: 4856/5000: Pérdida: [0.16342399] Aciertos: 0.97
# Epoch: 4857/5000: Pérdida: [0.16344227] Aciertos: 0.97
# Epoch: 4858/5000: Pérdida: [0.16346415] Aciertos: 0.97
# Epoch: 4859/5000: Pérdida: [0.16348974] Aciertos: 0.97
# Epoch: 4860/5000: Pérdida: [0.16351917] Aciertos: 0.97
# Epoch: 4861/5000: Pérdida: [0.16355258] Aciertos: 0.97
# Epoch: 4862/5000: Pérdida: [0.16359014] Aciertos: 0.97
# Epoch: 4863/5000: Pérdida: [0.16363203] Aciertos: 0.97
# Epoch: 4864/5000: Pérdida: [0.16367847] Aciertos: 0.97
# Epoch: 4865/5000: Pérdida: [0.16372967] Aciertos: 0.97
# Epoch: 4866/5000: Pérdida: [0.16378589] Aciertos: 0.97
# Epoch: 4867/5000: Pérdida: [0.16384739] Aciertos: 0.97
# Epoch: 4868/5000: Pérdida: [0.16391444] Aciertos: 0.97
# Epoch: 4869/5000: Pérdida: [0.16398732] Aciertos: 0.97
# Epoch: 4870/5000: Pérdida: [0.1640663] Aciertos: 0.97
# Epoch: 4871/5000: Pérdida: [0.16415166] Aciertos: 0.97
# Epoch: 4872/5000: Pérdida: [0.16424359] Aciertos: 0.97
# Epoch: 4873/5000: Pérdida: [0.16434227] Aciertos: 0.97
# Epoch: 4874/5000: Pérdida: [0.16444773] Aciertos: 0.97
# Epoch: 4875/5000: Pérdida: [0.16455983] Aciertos: 0.97
# Epoch: 4876/5000: Pérdida: [0.16467808] Aciertos: 0.97
# Epoch: 4877/5000: Pérdida: [0.16480112] Aciertos: 0.97
# Epoch: 4878/5000: Pérdida: [0.16492449] Aciertos: 0.97
# Epoch: 4879/5000: Pérdida: [0.16503224] Aciertos: 0.97
# Epoch: 4880/5000: Pérdida: [0.16507918] Aciertos: 0.97
# Epoch: 4881/5000: Pérdida: [0.16501098] Aciertos: 0.97
# Epoch: 4882/5000: Pérdida: [0.16492536] Aciertos: 0.97
# Epoch: 4883/5000: Pérdida: [0.16499817] Aciertos: 0.97
# Epoch: 4884/5000: Pérdida: [0.1650479] Aciertos: 0.97
# Epoch: 4885/5000: Pérdida: [0.16490798] Aciertos: 0.97
# Epoch: 4886/5000: Pérdida: [0.16479931] Aciertos: 0.97
# Epoch: 4887/5000: Pérdida: [0.16463577] Aciertos: 0.97
# Epoch: 4888/5000: Pérdida: [0.16435926] Aciertos: 0.97
# Epoch: 4889/5000: Pérdida: [0.16409577] Aciertos: 0.97
# Epoch: 4890/5000: Pérdida: [0.1638428] Aciertos: 0.97
# Epoch: 4891/5000: Pérdida: [0.16361915] Aciertos: 0.97
# Epoch: 4892/5000: Pérdida: [0.16341472] Aciertos: 0.97
# Epoch: 4893/5000: Pérdida: [0.16323563] Aciertos: 0.97
# Epoch: 4894/5000: Pérdida: [0.16307587] Aciertos: 0.97
# Epoch: 4895/5000: Pérdida: [0.16293611] Aciertos: 0.97
# Epoch: 4896/5000: Pérdida: [0.16281275] Aciertos: 0.97
# Epoch: 4897/5000: Pérdida: [0.1627048] Aciertos: 0.97
# Epoch: 4898/5000: Pérdida: [0.16261007] Aciertos: 0.97
# Epoch: 4899/5000: Pérdida: [0.16252733] Aciertos: 0.97
# Epoch: 4900/5000: Pérdida: [0.16245517] Aciertos: 0.97
# Epoch: 4901/5000: Pérdida: [0.16239256] Aciertos: 0.97
# Epoch: 4902/5000: Pérdida: [0.16233852] Aciertos: 0.97
# Epoch: 4903/5000: Pérdida: [0.16229224] Aciertos: 0.97
# Epoch: 4904/5000: Pérdida: [0.16225301] Aciertos: 0.97
# Epoch: 4905/5000: Pérdida: [0.16222023] Aciertos: 0.97
# Epoch: 4906/5000: Pérdida: [0.16219337] Aciertos: 0.97
# Epoch: 4907/5000: Pérdida: [0.16217199] Aciertos: 0.97
# Epoch: 4908/5000: Pérdida: [0.16215574] Aciertos: 0.97
# Epoch: 4909/5000: Pérdida: [0.16214439] Aciertos: 0.97
# Epoch: 4910/5000: Pérdida: [0.16213785] Aciertos: 0.97
# Epoch: 4911/5000: Pérdida: [0.16213634] Aciertos: 0.97
# Epoch: 4912/5000: Pérdida: [0.16214041] Aciertos: 0.97
# Epoch: 4913/5000: Pérdida: [0.16215115] Aciertos: 0.97
# Epoch: 4914/5000: Pérdida: [0.16217011] Aciertos: 0.97
# Epoch: 4915/5000: Pérdida: [0.16219883] Aciertos: 0.97
# Epoch: 4916/5000: Pérdida: [0.16223713] Aciertos: 0.97
# Epoch: 4917/5000: Pérdida: [0.1622764] Aciertos: 0.97
# Epoch: 4918/5000: Pérdida: [0.16226555] Aciertos: 0.97
# Epoch: 4919/5000: Pérdida: [0.16192305] Aciertos: 0.97
# Epoch: 4920/5000: Pérdida: [0.16393382] Aciertos: 0.97
# Epoch: 4921/5000: Pérdida: [0.24522069] Aciertos: 0.92
# Epoch: 4922/5000: Pérdida: [0.4618552] Aciertos: 0.85
# Epoch: 4923/5000: Pérdida: [0.24549392] Aciertos: 0.94
# Epoch: 4924/5000: Pérdida: [0.24862253] Aciertos: 0.92
# Epoch: 4925/5000: Pérdida: [0.50102939] Aciertos: 0.82
# Epoch: 4926/5000: Pérdida: [0.26944771] Aciertos: 0.92
# Epoch: 4927/5000: Pérdida: [0.15776254] Aciertos: 0.97
# Epoch: 4928/5000: Pérdida: [0.16502991] Aciertos: 0.97
# Epoch: 4929/5000: Pérdida: [0.16522784] Aciertos: 0.97
# Epoch: 4930/5000: Pérdida: [0.1610869] Aciertos: 0.97
# Epoch: 4931/5000: Pérdida: [0.1589765] Aciertos: 0.97
# Epoch: 4932/5000: Pérdida: [0.16085634] Aciertos: 0.97
# Epoch: 4933/5000: Pérdida: [0.15957082] Aciertos: 0.97
# Epoch: 4934/5000: Pérdida: [0.16059529] Aciertos: 0.97
# Epoch: 4935/5000: Pérdida: [0.15977155] Aciertos: 0.97
# Epoch: 4936/5000: Pérdida: [0.16049601] Aciertos: 0.97
# Epoch: 4937/5000: Pérdida: [0.15986243] Aciertos: 0.97
# Epoch: 4938/5000: Pérdida: [0.16042225] Aciertos: 0.97
# Epoch: 4939/5000: Pérdida: [0.15991646] Aciertos: 0.97
# Epoch: 4940/5000: Pérdida: [0.16037036] Aciertos: 0.97
# Epoch: 4941/5000: Pérdida: [0.159954] Aciertos: 0.97
# Epoch: 4942/5000: Pérdida: [0.16033307] Aciertos: 0.97
# Epoch: 4943/5000: Pérdida: [0.15998266] Aciertos: 0.97
# Epoch: 4944/5000: Pérdida: [0.16030586] Aciertos: 0.97
# Epoch: 4945/5000: Pérdida: [0.16000539] Aciertos: 0.97
# Epoch: 4946/5000: Pérdida: [0.16028543] Aciertos: 0.97
# Epoch: 4947/5000: Pérdida: [0.16002303] Aciertos: 0.97
# Epoch: 4948/5000: Pérdida: [0.16026898] Aciertos: 0.97
# Epoch: 4949/5000: Pérdida: [0.16003534] Aciertos: 0.97
# Epoch: 4950/5000: Pérdida: [0.16025397] Aciertos: 0.97
# Epoch: 4951/5000: Pérdida: [0.1600415] Aciertos: 0.97
# Epoch: 4952/5000: Pérdida: [0.16023807] Aciertos: 0.97
# Epoch: 4953/5000: Pérdida: [0.16004061] Aciertos: 0.97
# Epoch: 4954/5000: Pérdida: [0.16021922] Aciertos: 0.97
# Epoch: 4955/5000: Pérdida: [0.16003189] Aciertos: 0.97
# Epoch: 4956/5000: Pérdida: [0.16019572] Aciertos: 0.97
# Epoch: 4957/5000: Pérdida: [0.16001494] Aciertos: 0.97
# Epoch: 4958/5000: Pérdida: [0.16016627] Aciertos: 0.97
# Epoch: 4959/5000: Pérdida: [0.15998983] Aciertos: 0.97
# Epoch: 4960/5000: Pérdida: [0.16012992] Aciertos: 0.97
# Epoch: 4961/5000: Pérdida: [0.15995707] Aciertos: 0.97
# Epoch: 4962/5000: Pérdida: [0.16008602] Aciertos: 0.97
# Epoch: 4963/5000: Pérdida: [0.15991758] Aciertos: 0.97
# Epoch: 4964/5000: Pérdida: [0.16003416] Aciertos: 0.97
# Epoch: 4965/5000: Pérdida: [0.15987249] Aciertos: 0.97
# Epoch: 4966/5000: Pérdida: [0.15997427] Aciertos: 0.97
# Epoch: 4967/5000: Pérdida: [0.1598229] Aciertos: 0.97
# Epoch: 4968/5000: Pérdida: [0.15990664] Aciertos: 0.97
# Epoch: 4969/5000: Pérdida: [0.15976967] Aciertos: 0.97
# Epoch: 4970/5000: Pérdida: [0.15983216] Aciertos: 0.97
# Epoch: 4971/5000: Pérdida: [0.15971315] Aciertos: 0.97
# Epoch: 4972/5000: Pérdida: [0.15975234] Aciertos: 0.97
# Epoch: 4973/5000: Pérdida: [0.15965317] Aciertos: 0.97
# Epoch: 4974/5000: Pérdida: [0.15966915] Aciertos: 0.97
# Epoch: 4975/5000: Pérdida: [0.15958921] Aciertos: 0.97
# Epoch: 4976/5000: Pérdida: [0.15958465] Aciertos: 0.97
# Epoch: 4977/5000: Pérdida: [0.15952091] Aciertos: 0.97
# Epoch: 4978/5000: Pérdida: [0.15950051] Aciertos: 0.97
# Epoch: 4979/5000: Pérdida: [0.15944849] Aciertos: 0.97
# Epoch: 4980/5000: Pérdida: [0.15941774] Aciertos: 0.97
# Epoch: 4981/5000: Pérdida: [0.15937293] Aciertos: 0.97
# Epoch: 4982/5000: Pérdida: [0.1593367] Aciertos: 0.97
# Epoch: 4983/5000: Pérdida: [0.15929568] Aciertos: 0.97
# Epoch: 4984/5000: Pérdida: [0.15925741] Aciertos: 0.97
# Epoch: 4985/5000: Pérdida: [0.15921829] Aciertos: 0.97
# Epoch: 4986/5000: Pérdida: [0.15917996] Aciertos: 0.97
# Epoch: 4987/5000: Pérdida: [0.15914205] Aciertos: 0.97
# Epoch: 4988/5000: Pérdida: [0.15910461] Aciertos: 0.97
# Epoch: 4989/5000: Pérdida: [0.15906789] Aciertos: 0.97
# Epoch: 4990/5000: Pérdida: [0.15903177] Aciertos: 0.97
# Epoch: 4991/5000: Pérdida: [0.15899647] Aciertos: 0.97
# Epoch: 4992/5000: Pérdida: [0.15896194] Aciertos: 0.97
# Epoch: 4993/5000: Pérdida: [0.15892828] Aciertos: 0.97
# Epoch: 4994/5000: Pérdida: [0.15889552] Aciertos: 0.97
# Epoch: 4995/5000: Pérdida: [0.1588637] Aciertos: 0.97
# Epoch: 4996/5000: Pérdida: [0.15883285] Aciertos: 0.97
# Epoch: 4997/5000: Pérdida: [0.15880301] Aciertos: 0.97
# Epoch: 4998/5000: Pérdida: [0.15877419] Aciertos: 0.97
# Epoch: 4999/5000: Pérdida: [0.15874642] Aciertos: 0.97

# %% [markdown]
# Implementar el bucle de entrenamiento es una tarea complicada porque cada iteración requiere hacer el *forward propagation* y el *backpropagation* lo que, a su vez, implica llevar cuenta de resultados parciales para calcular cada uno de los gradientes con los que actualizar los parámetros.
#
# Además de la complejidad de organizar el código que lleve a cabo dicho algoritmo, se deben tener en cuenta los siguientes factores:
#  - El código debería permitir redes con cualquier número de capas las cuales, a su vez, deberán contener un número arbitrario de unidades. Incluso sería ideal que permitiese arquitecturas distinta de la red *feed forward*.
#  - El uso de memoria debe ser eficiente, no almacenando más resultados de los necesarios para cada cómputo.
#  - Del mismo modo, debería evitarse realizar operaciones innecesarias y paralelizar las que sea posible.
#  - El código debería ser extensible para permitir otras funciones de coste.
#
# Por todo ello es por lo que habitualmente se utilizan frameworks especializados como TensorFlow para trabajar con redes neuronales. Este tipo de software nos permite definir modelos y entrenarlos de manera eficiente sin que debamos preocuparnos de calcular derivadas ni de los detalles de implementación.
